# %%
import numpy as np
import pandas as pd
import os

import tensorflow as tf
import tensorflow_decision_forests as tfdf

print(f"Found TF-DF {tfdf.__version__}")
# Out:
# Found TF-DF 1.12.0

# %%
train_df = pd.read_csv("titanic/train.csv")
serving_df = pd.read_csv("titanic/test.csv")

train_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                               Name     Sex   Age  SibSp  \
# 0                            Braund Mr Owen Harris    male  22.0      1
# 1  Cumings Mrs John Bradley Florence Briggs Thayer  female  38.0      1
# 2                             Heikkinen Miss Laina  female  26.0      0
# 3         Futrelle Mrs Jacques Heath Lily May Peel  female  35.0      1
# 4                           Allen Mr William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Ticket_number Ticket_item
# 0      0         A/5 21171   7.2500   NaN        S         21171         A/5
# 1      0          PC 17599  71.2833   C85        C         17599          PC
# 2      0  STON/O2. 3101282   7.9250   NaN        S       3101282    STON/O2.
# 3      0            113803  53.1000  C123        S        113803        NONE
# 4      0            373450   8.0500   NaN        S        373450        NONE

# %%
input_features = list(preprocessed_train_df.columns)
input_features.remove("Ticket")
input_features.remove("PassengerId")
input_features.remove("Survived")
#input_features.remove("Ticket_number")

print(f"Input features: {input_features}")
# Out:
# Input features: ['Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Cabin', 'Embarked', 'Ticket_number', 'Ticket_item']

# %%
def tokenize_names(features, labels=None):
    """Divite the names into tokens. TF-DF can consume text tokens natively."""
    features["Name"] =  tf.strings.split(features["Name"])
    return features, labels

train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(preprocessed_train_df,label="Survived").map(tokenize_names)
serving_ds = tfdf.keras.pd_dataframe_to_tf_dataset(preprocessed_serving_df).map(tokenize_names)

# %%
tuner = tfdf.tuner.RandomSearch(num_trials=1000)
tuner.choice("min_examples", [2, 5, 7, 10])
tuner.choice("categorical_algorithm", ["CART", "RANDOM"])

local_search_space = tuner.choice("growing_strategy", ["LOCAL"])
local_search_space.choice("max_depth", [3, 4, 5, 6, 8])

global_search_space = tuner.choice("growing_strategy", ["BEST_FIRST_GLOBAL"], merge=True)
global_search_space.choice("max_num_nodes", [16, 32, 64, 128, 256])

#tuner.choice("use_hessian_gain", [True, False])
tuner.choice("shrinkage", [0.02, 0.05, 0.10, 0.15])
tuner.choice("num_candidate_attributes_ratio", [0.2, 0.5, 0.9, 1.0])


tuner.choice("split_axis", ["AXIS_ALIGNED"])
oblique_space = tuner.choice("split_axis", ["SPARSE_OBLIQUE"], merge=True)
oblique_space.choice("sparse_oblique_normalization",
                     ["NONE", "STANDARD_DEVIATION", "MIN_MAX"])
oblique_space.choice("sparse_oblique_weights", ["BINARY", "CONTINUOUS"])
oblique_space.choice("sparse_oblique_num_projections_exponent", [1.0, 1.5])

# Tune the model. Notice the `tuner=tuner`.
tuned_model = tfdf.keras.GradientBoostedTreesModel(tuner=tuner)
tuned_model.fit(train_ds, verbose=0)

tuned_self_evaluation = tuned_model.make_inspector().evaluation()
print(f"Accuracy: {tuned_self_evaluation.accuracy} Loss:{tuned_self_evaluation.loss}")
# Out:
# Use /tmp/tmp4s1jmnoi as temporary training directory
# W0000 00:00:1751286348.961503   13176 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751286348.961526   13176 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751286348.961530   13176 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1751286349.134952   13176 kernel.cc:782] Start Yggdrasil model training
# I0000 00:00:1751286349.134968   13176 kernel.cc:783] Collect training examples
# I0000 00:00:1751286349.134988   13176 kernel.cc:795] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: false
# detect_numerical_as_discretized_numerical: false
#
# I0000 00:00:1751286349.135038   13176 kernel.cc:401] Number of batches: 1
# I0000 00:00:1751286349.135043   13176 kernel.cc:402] Number of examples: 891
# I0000 00:00:1751286349.135547   13176 data_spec_inference.cc:354] 147 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Cabin (0 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751286349.135812   13176 data_spec_inference.cc:354] 1441 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Name (85 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751286349.135996   13176 data_spec_inference.cc:354] 673 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket (8 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751286349.136044   13176 data_spec_inference.cc:354] 28 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_item (16 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751286349.136154   13176 data_spec_inference.cc:354] 671 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_number (8 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751286349.136513   13176 kernel.cc:802] Training dataset:
# Number of records: 891
# Number of columns: 14
#
# Number of columns by type:
# 	CATEGORICAL: 7 (50%)
# 	NUMERICAL: 6 (42.8571%)
# 	CATEGORICAL_SET: 1 (7.14286%)
#
# Columns:
#
# CATEGORICAL: 7 (50%)
# 	1: "Cabin" CATEGORICAL num-nas:687 (77.1044%) has-dict vocab-size:1 num-oods:204 (100%)
# 	2: "Embarked" CATEGORICAL num-nas:2 (0.224467%) has-dict vocab-size:4 zero-ood-items most-frequent:"S" 644 (72.4409%)
# 	8: "Sex" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"male" 577 (64.7587%)
# 	10: "Ticket" CATEGORICAL has-dict vocab-size:9 num-oods:842 (94.5006%) most-frequent:"<OOD>" 842 (94.5006%)
# 	11: "Ticket_item" CATEGORICAL has-dict vocab-size:17 num-oods:46 (5.16274%) most-frequent:"NONE" 665 (74.6352%)
# 	12: "Ticket_number" CATEGORICAL has-dict vocab-size:9 num-oods:842 (94.5006%) most-frequent:"<OOD>" 842 (94.5006%)
# 	13: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 6 (42.8571%)
# 	0: "Age" NUMERICAL num-nas:177 (19.8653%) mean:29.6991 min:0.42 max:80 sd:14.5163
# 	3: "Fare" NUMERICAL mean:32.2042 min:0 max:512.329 sd:49.6655
# 	5: "Parch" NUMERICAL mean:0.381594 min:0 max:6 sd:0.805605
# 	6: "PassengerId" NUMERICAL mean:446 min:1 max:891 sd:257.209
# 	7: "Pclass" NUMERICAL mean:2.30864 min:1 max:3 sd:0.835602
# 	9: "SibSp" NUMERICAL mean:0.523008 min:0 max:8 sd:1.10212
#
# CATEGORICAL_SET: 1 (7.14286%)
# 	4: "Name" CATEGORICAL_SET has-dict vocab-size:86 num-oods:1932 (216.835%) most-frequent:"<OOD>" 1932 (216.835%)
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1751286349.136533   13176 kernel.cc:818] Configure learner
# W0000 00:00:1751286349.136701   13176 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751286349.136706   13176 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751286349.136707   13176 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1751286349.136737   13176 kernel.cc:831] Training config:
# learner: "HYPERPARAMETER_OPTIMIZER"
# features: "^Age$"
# features: "^Cabin$"
# features: "^Embarked$"
# features: "^Fare$"
# features: "^Name$"
# features: "^Parch$"
# features: "^PassengerId$"
# features: "^Pclass$"
# features: "^Sex$"
# features: "^SibSp$"
# features: "^Ticket$"
# features: "^Ticket_item$"
# features: "^Ticket_number$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# metadata {
#   framework: "TF Keras"
# }
# [yggdrasil_decision_forests.model.hyperparameters_optimizer_v2.proto.hyperparameters_optimizer_config] {
#   base_learner {
#     learner: "GRADIENT_BOOSTED_TREES"
#     features: "^Age$"
#     features: "^Cabin$"
#     features: "^Embarked$"
#     features: "^Fare$"
#     features: "^Name$"
#     features: "^Parch$"
#     features: "^PassengerId$"
#     features: "^Pclass$"
#     features: "^Sex$"
#     features: "^SibSp$"
#     features: "^Ticket$"
#     features: "^Ticket_item$"
#     features: "^Ticket_number$"
#     label: "^__LABEL$"
#     task: CLASSIFICATION
#     random_seed: 123456
#     pure_serving_model: false
#     [yggdrasil_decision_forests.model.gradient_boosted_trees.proto.gradient_boosted_trees_config] {
#       num_trees: 300
#       decision_tree {
#         max_depth: 6
#         min_examples: 5
#         in_split_min_examples_check: true
#         keep_non_leaf_label_distribution: true
#         num_candidate_attributes: -1
#         missing_value_policy: GLOBAL_IMPUTATION
#         allow_na_conditions: false
#         categorical_set_greedy_forward {
#           sampling: 0.1
#           max_num_items: -1
#           min_item_frequency: 1
#         }
#         growing_strategy_local {
#         }
#         categorical {
#           cart {
#           }
#         }
#         axis_aligned_split {
#         }
#         internal {
#           sorting_strategy: PRESORTED
#         }
#         uplift {
#           min_examples_in_treatment: 5
#           split_score: KULLBACK_LEIBLER
#         }
#         numerical_vector_sequence {
#           max_num_test_examples: 1000
#           num_random_selected_anchors: 100
#         }
#       }
#       shrinkage: 0.1
#       loss: DEFAULT
#       validation_set_ratio: 0.1
#       validation_interval_in_trees: 1
#       early_stopping: VALIDATION_LOSS_INCREASE
#       early_stopping_num_trees_look_ahead: 30
#       l2_regularization: 0
#       lambda_loss: 1
#       mart {
#       }
#       adapt_subsample_for_maximum_training_duration: false
#       l1_regularization: 0
#       use_hessian_gain: false
#       l2_regularization_categorical: 1
#       xe_ndcg {
#         ndcg_truncation: 5
#       }
#       stochastic_gradient_boosting {
#         ratio: 1
#       }
#       apply_link_function: true
#       compute_permutation_variable_importance: false
#       early_stopping_initial_iteration: 10
#     }
#   }
#   optimizer {
#     optimizer_key: "RANDOM"
#     [yggdrasil_decision_forests.model.hyperparameters_optimizer_v2.proto.random] {
#       num_trials: 1000
#     }
#   }
#   search_space {
#     fields {
#       name: "min_examples"
#       discrete_candidates {
#         possible_values {
#           integer: 2
#         }
#         possible_values {
#           integer: 5
#         }
#         possible_values {
#           integer: 7
#         }
#         possible_values {
#           integer: 10
#         }
#       }
#     }
#     fields {
#       name: "categorical_algorithm"
#       discrete_candidates {
#         possible_values {
#           categorical: "CART"
#         }
#         possible_values {
#           categorical: "RANDOM"
#         }
#       }
#     }
#     fields {
#       name: "growing_strategy"
#       discrete_candidates {
#         possible_values {
#           categorical: "LOCAL"
#         }
#         possible_values {
#           categorical: "BEST_FIRST_GLOBAL"
#         }
#       }
#       children {
#         name: "max_depth"
#         discrete_candidates {
#           possible_values {
#             integer: 3
#           }
#           possible_values {
#             integer: 4
#           }
#           possible_values {
#             integer: 5
#           }
#           possible_values {
#             integer: 6
#           }
#           possible_values {
#             integer: 8
#           }
#         }
#         parent_discrete_values {
#           possible_values {
#             categorical: "LOCAL"
#           }
#         }
#       }
#       children {
#         name: "max_num_nodes"
#         discrete_candidates {
#           possible_values {
#             integer: 16
#           }
#           possible_values {
#             integer: 32
#           }
#           possible_values {
#             integer: 64
#           }
#           possible_values {
#             integer: 128
#           }
#           possible_values {
#             integer: 256
#           }
#         }
#         parent_discrete_values {
#           possible_values {
#             categorical: "BEST_FIRST_GLOBAL"
#           }
#         }
#       }
#     }
#     fields {
#       name: "shrinkage"
#       discrete_candidates {
#         possible_values {
#           real: 0.02
#         }
#         possible_values {
#           real: 0.05
#         }
#         possible_values {
#           real: 0.1
#         }
#         possible_values {
#           real: 0.15
#         }
#       }
#     }
#     fields {
#       name: "num_candidate_attributes_ratio"
#       discrete_candidates {
#         possible_values {
#           real: 0.2
#         }
#         possible_values {
#           real: 0.5
#         }
#         possible_values {
#           real: 0.9
#         }
#         possible_values {
#           real: 1
#         }
#       }
#     }
#     fields {
#       name: "split_axis"
#       discrete_candidates {
#         possible_values {
#           categorical: "AXIS_ALIGNED"
#         }
#         possible_values {
#           categorical: "SPARSE_OBLIQUE"
#         }
#       }
#       children {
#         name: "sparse_oblique_normalization"
#         discrete_candidates {
#           possible_values {
#             categorical: "NONE"
#           }
#           possible_values {
#             categorical: "STANDARD_DEVIATION"
#           }
#           possible_values {
#             categorical: "MIN_MAX"
#           }
#         }
#         parent_discrete_values {
#           possible_values {
#             categorical: "SPARSE_OBLIQUE"
#           }
#         }
#       }
#       children {
#         name: "sparse_oblique_weights"
#         discrete_candidates {
#           possible_values {
#             categorical: "BINARY"
#           }
#           possible_values {
#             categorical: "CONTINUOUS"
#           }
#         }
#         parent_discrete_values {
#           possible_values {
#             categorical: "SPARSE_OBLIQUE"
#           }
#         }
#       }
#       children {
#         name: "sparse_oblique_num_projections_exponent"
#         discrete_candidates {
#           possible_values {
#             real: 1
#           }
#           possible_values {
#             real: 1.5
#           }
#         }
#         parent_discrete_values {
#           possible_values {
#             categorical: "SPARSE_OBLIQUE"
#           }
#         }
#       }
#     }
#   }
#   base_learner_deployment {
#     num_threads: 1
#   }
# }
#
# I0000 00:00:1751286349.136979   13176 kernel.cc:834] Deployment config:
# cache_path: "/tmp/tmp4s1jmnoi/working_cache"
# num_threads: 8
# try_resume_training: true
#
# I0000 00:00:1751286349.137106   15964 kernel.cc:895] Train model
# I0000 00:00:1751286349.137296   15964 hyperparameters_optimizer.cc:210] Hyperparameter search space:
# fields {
#   name: "min_examples"
#   discrete_candidates {
#     possible_values {
#       integer: 2
#     }
#     possible_values {
#       integer: 5
#     }
#     possible_values {
#       integer: 7
#     }
#     possible_values {
#       integer: 10
#     }
#   }
# }
# fields {
#   name: "categorical_algorithm"
#   discrete_candidates {
#     possible_values {
#       categorical: "CART"
#     }
#     possible_values {
#       categorical: "RANDOM"
#     }
#   }
# }
# fields {
#   name: "growing_strategy"
#   discrete_candidates {
#     possible_values {
#       categorical: "LOCAL"
#     }
#     possible_values {
#       categorical: "BEST_FIRST_GLOBAL"
#     }
#   }
#   children {
#     name: "max_depth"
#     discrete_candidates {
#       possible_values {
#         integer: 3
#       }
#       possible_values {
#         integer: 4
#       }
#       possible_values {
#         integer: 5
#       }
#       possible_values {
#         integer: 6
#       }
#       possible_values {
#         integer: 8
#       }
#     }
#     parent_discrete_values {
#       possible_values {
#         categorical: "LOCAL"
#       }
#     }
#   }
#   children {
#     name: "max_num_nodes"
#     discrete_candidates {
#       possible_values {
#         integer: 16
#       }
#       possible_values {
#         integer: 32
#       }
#       possible_values {
#         integer: 64
#       }
#       possible_values {
#         integer: 128
#       }
#       possible_values {
#         integer: 256
#       }
#     }
#     parent_discrete_values {
#       possible_values {
#         categorical: "BEST_FIRST_GLOBAL"
#       }
#     }
#   }
# }
# fields {
#   name: "shrinkage"
#   discrete_candidates {
#     possible_values {
#       real: 0.02
#     }
#     possible_values {
#       real: 0.05
#     }
#     possible_values {
#       real: 0.1
#     }
#     possible_values {
#       real: 0.15
#     }
#   }
# }
# fields {
#   name: "num_candidate_attributes_ratio"
#   discrete_candidates {
#     possible_values {
#       real: 0.2
#     }
#     possible_values {
#       real: 0.5
#     }
#     possible_values {
#       real: 0.9
#     }
#     possible_values {
#       real: 1
#     }
#   }
# }
# fields {
#   name: "split_axis"
#   discrete_candidates {
#     possible_values {
#       categorical: "AXIS_ALIGNED"
#     }
#     possible_values {
#       categorical: "SPARSE_OBLIQUE"
#     }
#   }
#   children {
#     name: "sparse_oblique_normalization"
#     discrete_candidates {
#       possible_values {
#         categorical: "NONE"
#       }
#       possible_values {
#         categorical: "STANDARD_DEVIATION"
#       }
#       possible_values {
#         categorical: "MIN_MAX"
#       }
#     }
#     parent_discrete_values {
#       possible_values {
#         categorical: "SPARSE_OBLIQUE"
#       }
#     }
#   }
#   children {
#     name: "sparse_oblique_weights"
#     discrete_candidates {
#       possible_values {
#         categorical: "BINARY"
#       }
#       possible_values {
#         categorical: "CONTINUOUS"
#       }
#     }
#     parent_discrete_values {
#       possible_values {
#         categorical: "SPARSE_OBLIQUE"
#       }
#     }
#   }
#   children {
#     name: "sparse_oblique_num_projections_exponent"
#     discrete_candidates {
#       possible_values {
#         real: 1
#       }
#       possible_values {
#         real: 1.5
#       }
#     }
#     parent_discrete_values {
#       possible_values {
#         categorical: "SPARSE_OBLIQUE"
#       }
#     }
#   }
# }
#
# I0000 00:00:1751286349.137413   15964 hyperparameters_optimizer.cc:494] Start local tuner with 1 parallel trial(s), each with 8 thread(s)
# I0000 00:00:1751286349.138279   15965 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751286349.138306   15965 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 13 feature(s).
# I0000 00:00:1751286349.139122   15965 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1751286349.139221   15965 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751286349.143480   15965 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.275224 train-accuracy:0.612469 valid-loss:1.244961 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286349.147838   15965 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.218663 train-accuracy:0.612469 valid-loss:1.195136 valid-accuracy:0.657534 [total:0.01s iter:0.00s]
# I0000 00:00:1751286349.153145   15965 gradient_boosted_trees.cc:1634] Train tree 3/300 train-loss:1.164678 train-accuracy:0.612469 valid-loss:1.150744 valid-accuracy:0.657534 [total:0.01s iter:0.01s]
# I0000 00:00:1751286349.520202   15965 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.78161
# I0000 00:00:1751286349.520229   15965 gradient_boosted_trees.cc:279] Truncates the model to 55 tree(s) i.e. 55  iteration(s).
# I0000 00:00:1751286349.520538   15965 gradient_boosted_trees.cc:341] Final model num-trees:55 valid-loss:0.781610 valid-accuracy:0.835616
# I0000 00:00:1751286349.521867   15964 hyperparameters_optimizer.cc:578] [1/1000] Score: -0.78161 / -0.78161 HParams: fields { name: "min_examples" value { integer: 2 } } fields { name: "categorical_algorithm" value { categorical: "RANDOM" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 32 } } fields { name: "shrinkage" value { real: 0.05 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.9 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "MIN_MAX" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1751286349.522143   15965 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751286349.522170   15965 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 13 feature(s).
# I0000 00:00:1751286349.522559   15965 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1751286349.522616   15965 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751286349.525324   15965 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.286014 train-accuracy:0.612469 valid-loss:1.247438 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286349.527790   15965 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.238554 train-accuracy:0.612469 valid-loss:1.198752 valid-accuracy:0.657534 [total:0.01s iter:0.00s]
# I0000 00:00:1751286349.751191   15965 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.741661
# I0000 00:00:1751286349.751218   15965 gradient_boosted_trees.cc:279] Truncates the model to 51 tree(s) i.e. 51  iteration(s).
# I0000 00:00:1751286349.751385   15965 gradient_boosted_trees.cc:341] Final model num-trees:51 valid-loss:0.741661 valid-accuracy:0.835616
# I0000 00:00:1751286349.752668   15965 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751286349.752701   15965 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 13 feature(s).
# I0000 00:00:1751286349.753180   15964 hyperparameters_optimizer.cc:578] [2/1000] Score: -0.741661 / -0.741661 HParams: fields { name: "min_examples" value { integer: 7 } } fields { name: "categorical_algorithm" value { categorical: "RANDOM" } } fields { name: "growing_strategy" value { categorical: "LOCAL" } } fields { name: "max_depth" value { integer: 6 } } fields { name: "shrinkage" value { real: 0.05 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.2 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "STANDARD_DEVIATION" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1751286349.753303   15965 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1751286349.753357   15965 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751286349.755070   15965 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.282273 train-accuracy:0.612469 valid-loss:1.248528 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286349.756689   15965 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.236855 train-accuracy:0.612469 valid-loss:1.209148 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286349.881527   15965 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.751521
# I0000 00:00:1751286349.881552   15965 gradient_boosted_trees.cc:279] Truncates the model to 39 tree(s) i.e. 39  iteration(s).
# I0000 00:00:1751286349.881783   15965 gradient_boosted_trees.cc:341] Final model num-trees:39 valid-loss:0.751521 valid-accuracy:0.876712
# I0000 00:00:1751286349.882507   15964 hyperparameters_optimizer.cc:578] [3/1000] Score: -0.751521 / -0.741661 HParams: fields { name: "min_examples" value { integer: 10 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "LOCAL" } } fields { name: "max_depth" value { integer: 6 } } fields { name: "shrinkage" value { real: 0.05 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.9 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "STANDARD_DEVIATION" } } fields { name: "sparse_oblique_weights" value { categorical: "BINARY" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1 } }
# I0000 00:00:1751286349.882946   15965 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751286349.882955   15965 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 13 feature(s).
# I0000 00:00:1751286349.883311   15965 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1751286349.883365   15965 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751286349.886193   15965 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.181362 train-accuracy:0.612469 valid-loss:1.168565 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286349.888745   15965 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.069673 train-accuracy:0.820293 valid-loss:1.077854 valid-accuracy:0.808219 [total:0.01s iter:0.00s]
# I0000 00:00:1751286350.053967   15965 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.774847
# I0000 00:00:1751286350.053992   15965 gradient_boosted_trees.cc:279] Truncates the model to 19 tree(s) i.e. 19  iteration(s).
# I0000 00:00:1751286350.054157   15965 gradient_boosted_trees.cc:341] Final model num-trees:19 valid-loss:0.774847 valid-accuracy:0.849315
# I0000 00:00:1751286350.054649   15964 hyperparameters_optimizer.cc:578] [4/1000] Score: -0.774847 / -0.741661 HParams: fields { name: "min_examples" value { integer: 10 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 16 } } fields { name: "shrinkage" value { real: 0.15 } } fields { name: "num_candidate_attributes_ratio" value { real: 1 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "MIN_MAX" } } fields { name: "sparse_oblique_weights" value { categorical: "BINARY" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1751286350.055049   15965 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751286350.055061   15965 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 13 feature(s).
# I0000 00:00:1751286350.055413   15965 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1751286350.055467   15965 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751286350.056937   15965 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.296600 train-accuracy:0.612469 valid-loss:1.257550 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286350.058198   15965 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.267403 train-accuracy:0.612469 valid-loss:1.225554 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286350.186833   15965 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.74207
# I0000 00:00:1751286350.186857   15965 gradient_boosted_trees.cc:279] Truncates the model to 84 tree(s) i.e. 84  iteration(s).
# I0000 00:00:1751286350.186892   15965 gradient_boosted_trees.cc:341] Final model num-trees:84 valid-loss:0.742070 valid-accuracy:0.849315
# I0000 00:00:1751286350.187172   15964 hyperparameters_optimizer.cc:578] [5/1000] Score: -0.74207 / -0.741661 HParams: fields { name: "min_examples" value { integer: 2 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "LOCAL" } } fields { name: "max_depth" value { integer: 3 } } fields { name: "shrinkage" value { real: 0.05 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.5 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "MIN_MAX" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1751286350.187512   15965 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751286350.187521   15965 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 13 feature(s).
# I0000 00:00:1751286350.187895   15965 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1751286350.187988   15965 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751286350.190101   15965 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.278595 train-accuracy:0.612469 valid-loss:1.244489 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286350.192595   15965 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.225286 train-accuracy:0.612469 valid-loss:1.196103 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286350.381242   15965 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.744574
# I0000 00:00:1751286350.381273   15965 gradient_boosted_trees.cc:279] Truncates the model to 47 tree(s) i.e. 47  iteration(s).
# I0000 00:00:1751286350.381655   15965 gradient_boosted_trees.cc:341] Final model num-trees:47 valid-loss:0.744574 valid-accuracy:0.821918
# I0000 00:00:1751286350.383002   15964 hyperparameters_optimizer.cc:578] [6/1000] Score: -0.744574 / -0.741661 HParams: fields { name: "min_examples" value { integer: 7 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 128 } } fields { name: "shrinkage" value { real: 0.05 } } fields { name: "num_candidate_attributes_ratio" value { real: 1 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "MIN_MAX" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1 } }
# I0000 00:00:1751286350.383419   15965 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751286350.383490   15965 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 13 feature(s).
# I0000 00:00:1751286350.383963   15965 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1751286350.384018   15965 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751286350.388019   15965 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.277783 train-accuracy:0.612469 valid-loss:1.246017 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286350.392776   15965 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.226754 train-accuracy:0.612469 valid-loss:1.199931 valid-accuracy:0.657534 [total:0.01s iter:0.00s]
# I0000 00:00:1751286350.679720   15965 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.751534
# I0000 00:00:1751286350.679745   15965 gradient_boosted_trees.cc:279] Truncates the model to 38 tree(s) i.e. 38  iteration(s).
# I0000 00:00:1751286350.680072   15965 gradient_boosted_trees.cc:341] Final model num-trees:38 valid-loss:0.751534 valid-accuracy:0.849315
# I0000 00:00:1751286350.681072   15964 hyperparameters_optimizer.cc:578] [7/1000] Score: -0.751534 / -0.741661 HParams: fields { name: "min_examples" value { integer: 10 } } fields { name: "categorical_algorithm" value { categorical: "RANDOM" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 64 } } fields { name: "shrinkage" value { real: 0.05 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.9 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "MIN_MAX" } } fields { name: "sparse_oblique_weights" value { categorical: "BINARY" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1751286350.681478   15965 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751286350.681502   15965 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 13 feature(s).
# I0000 00:00:1751286350.682098   15965 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1751286350.682168   15965 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751286350.683213   15965 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.319558 train-accuracy:0.612469 valid-loss:1.279173 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286350.684378   15965 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.304379 train-accuracy:0.612469 valid-loss:1.261729 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286350.937479   15965 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.726496
# I0000 00:00:1751286350.937502   15965 gradient_boosted_trees.cc:279] Truncates the model to 177 tree(s) i.e. 177  iteration(s).
# I0000 00:00:1751286350.937549   15965 gradient_boosted_trees.cc:341] Final model num-trees:177 valid-loss:0.726496 valid-accuracy:0.863014
# I0000 00:00:1751286350.938543   15965 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751286350.938583   15965 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 13 feature(s).
# I0000 00:00:1751286350.938632   15964 hyperparameters_optimizer.cc:578] [8/1000] Score: -0.726496 / -0.726496 HParams: fields { name: "min_examples" value { integer: 10 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "LOCAL" } } fields { name: "max_depth" value { integer: 3 } } fields { name: "shrinkage" value { real: 0.02 } } fields { name: "num_candidate_attributes_ratio" value { real: 1 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "MIN_MAX" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1751286350.938954   15965 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1751286350.939005   15965 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751286350.943628   15965 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.219501 train-accuracy:0.612469 valid-loss:1.197047 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286350.948024   15965 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.124701 train-accuracy:0.772616 valid-loss:1.114994 valid-accuracy:0.767123 [total:0.01s iter:0.00s]
# I0000 00:00:1751286351.177376   15965 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.814196
# I0000 00:00:1751286351.177402   15965 gradient_boosted_trees.cc:279] Truncates the model to 22 tree(s) i.e. 22  iteration(s).
# I0000 00:00:1751286351.177736   15965 gradient_boosted_trees.cc:341] Final model num-trees:22 valid-loss:0.814196 valid-accuracy:0.835616
# I0000 00:00:1751286351.178603   15964 hyperparameters_optimizer.cc:578] [9/1000] Score: -0.814196 / -0.726496 HParams: fields { name: "min_examples" value { integer: 2 } } fields { name: "categorical_algorithm" value { categorical: "RANDOM" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 128 } } fields { name: "shrinkage" value { real: 0.1 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.9 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "STANDARD_DEVIATION" } } fields { name: "sparse_oblique_weights" value { categorical: "BINARY" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1751286351.179164   15965 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751286351.179173   15965 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 13 feature(s).
# I0000 00:00:1751286351.179567   15965 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1751286351.179625   15965 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751286351.181306   15965 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.181235 train-accuracy:0.612469 valid-loss:1.180698 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286351.182893   15965 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.065842 train-accuracy:0.800734 valid-loss:1.083414 valid-accuracy:0.753425 [total:0.00s iter:0.00s]
# I0000 00:00:1751286351.248624   15965 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.746979
# I0000 00:00:1751286351.248648   15965 gradient_boosted_trees.cc:279] Truncates the model to 13 tree(s) i.e. 13  iteration(s).
# I0000 00:00:1751286351.248877   15965 gradient_boosted_trees.cc:341] Final model num-trees:13 valid-loss:0.746979 valid-accuracy:0.863014
# I0000 00:00:1751286351.249354   15964 hyperparameters_optimizer.cc:578] [10/1000] Score: -0.746979 / -0.726496 HParams: fields { name: "min_examples" value { integer: 5 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 32 } } fields { name: "shrinkage" value { real: 0.15 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.2 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "STANDARD_DEVIATION" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1 } }
# I0000 00:00:1751286351.249698   15965 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751286351.249708   15965 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 13 feature(s).
# I0000 00:00:1751286351.250084   15965 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1751286351.250135   15965 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751286351.253572   15965 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.312632 train-accuracy:0.612469 valid-loss:1.275846 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286351.257046   15965 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.290870 train-accuracy:0.612469 valid-loss:1.258596 valid-accuracy:0.657534 [total:0.01s iter:0.00s]
# I0000 00:00:1751286351.789401   15965 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.767304
# I0000 00:00:1751286351.789428   15965 gradient_boosted_trees.cc:279] Truncates the model to 124 tree(s) i.e. 124  iteration(s).
# I0000 00:00:1751286351.789680   15965 gradient_boosted_trees.cc:341] Final model num-trees:124 valid-loss:0.767304 valid-accuracy:0.835616
# I0000 00:00:1751286351.793361   15964 hyperparameters_optimizer.cc:578] [11/1000] Score: -0.767304 / -0.726496 HParams: fields { name: "min_examples" value { integer: 10 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 128 } } fields { name: "shrinkage" value { real: 0.02 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.5 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "STANDARD_DEVIATION" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1751286351.793728   15965 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751286351.793754   15965 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 13 feature(s).
# I0000 00:00:1751286351.794778   15965 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1751286351.794932   15965 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751286351.799482   15965 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.222900 train-accuracy:0.612469 valid-loss:1.198899 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286351.803315   15965 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.131610 train-accuracy:0.779951 valid-loss:1.123520 valid-accuracy:0.808219 [total:0.01s iter:0.00s]
# I0000 00:00:1751286352.004056   15965 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.768521
# I0000 00:00:1751286352.004085   15965 gradient_boosted_trees.cc:279] Truncates the model to 21 tree(s) i.e. 21  iteration(s).
# I0000 00:00:1751286352.004536   15965 gradient_boosted_trees.cc:341] Final model num-trees:21 valid-loss:0.768521 valid-accuracy:0.849315
# I0000 00:00:1751286352.005577   15964 hyperparameters_optimizer.cc:578] [12/1000] Score: -0.768521 / -0.726496 HParams: fields { name: "min_examples" value { integer: 7 } } fields { name: "categorical_algorithm" value { categorical: "RANDOM" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 64 } } fields { name: "shrinkage" value { real: 0.1 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.5 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "STANDARD_DEVIATION" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1751286352.006147   15965 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751286352.006160   15965 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 13 feature(s).
# I0000 00:00:1751286352.006676   15965 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1751286352.006755   15965 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751286352.012960   15965 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.272833 train-accuracy:0.612469 valid-loss:1.237238 valid-accuracy:0.657534 [total:0.01s iter:0.01s]
# I0000 00:00:1751286352.017851   15965 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.217204 train-accuracy:0.612469 valid-loss:1.197386 valid-accuracy:0.657534 [total:0.01s iter:0.00s]
# I0000 00:00:1751286352.361222   15965 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.7152
# I0000 00:00:1751286352.361245   15965 gradient_boosted_trees.cc:279] Truncates the model to 36 tree(s) i.e. 36  iteration(s).
# I0000 00:00:1751286352.361632   15965 gradient_boosted_trees.cc:341] Final model num-trees:36 valid-loss:0.715200 valid-accuracy:0.876712
# I0000 00:00:1751286352.363502   15965 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751286352.363535   15965 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 13 feature(s).
# I0000 00:00:1751286352.363576   15964 hyperparameters_optimizer.cc:578] [13/1000] Score: -0.7152 / -0.7152 HParams: fields { name: "min_examples" value { integer: 5 } } fields { name: "categorical_algorithm" value { categorical: "RANDOM" } } fields { name: "growing_strategy" value { categorical: "LOCAL" } } fields { name: "max_depth" value { integer: 8 } } fields { name: "shrinkage" value { real: 0.05 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.9 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "MIN_MAX" } } fields { name: "sparse_oblique_weights" value { categorical: "BINARY" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1751286352.363942   15965 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1751286352.363994   15965 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751286352.366798   15965 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.282608 train-accuracy:0.612469 valid-loss:1.249774 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286352.369654   15965 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.232422 train-accuracy:0.612469 valid-loss:1.201856 valid-accuracy:0.657534 [total:0.01s iter:0.00s]
# I0000 00:00:1751286352.609202   15965 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.753689
# I0000 00:00:1751286352.609225   15965 gradient_boosted_trees.cc:279] Truncates the model to 45 tree(s) i.e. 45  iteration(s).
# I0000 00:00:1751286352.609365   15965 gradient_boosted_trees.cc:341] Final model num-trees:45 valid-loss:0.753689 valid-accuracy:0.863014
# I0000 00:00:1751286352.610040   15964 hyperparameters_optimizer.cc:578] [14/1000] Score: -0.753689 / -0.7152 HParams: fields { name: "min_examples" value { integer: 7 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 16 } } fields { name: "shrinkage" value { real: 0.05 } } fields { name: "num_candidate_attributes_ratio" value { real: 1 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "STANDARD_DEVIATION" } } fields { name: "sparse_oblique_weights" value { categorical: "BINARY" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1751286352.610472   15965 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751286352.610502   15965 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 13 feature(s).
# I0000 00:00:1751286352.610924   15965 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1751286352.611273   15965 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751286352.611674   15965 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.296600 train-accuracy:0.612469 valid-loss:1.257550 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286352.612387   15965 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.262156 train-accuracy:0.612469 valid-loss:1.225177 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286352.670170   15965 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.745735
# I0000 00:00:1751286352.670194   15965 gradient_boosted_trees.cc:279] Truncates the model to 93 tree(s) i.e. 93  iteration(s).
# I0000 00:00:1751286352.670223   15965 gradient_boosted_trees.cc:341] Final model num-trees:93 valid-loss:0.745735 valid-accuracy:0.849315
# I0000 00:00:1751286352.670484   15964 hyperparameters_optimizer.cc:578] [15/1000] Score: -0.745735 / -0.7152 HParams: fields { name: "min_examples" value { integer: 7 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "LOCAL" } } fields { name: "max_depth" value { integer: 3 } } fields { name: "shrinkage" value { real: 0.05 } } fields { name: "num_candidate_attributes_ratio" value { real: 1 } } fields { name: "split_axis" value { categorical: "AXIS_ALIGNED" } }
# I0000 00:00:1751286352.670834   15965 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751286352.670859   15965 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 13 feature(s).
# I0000 00:00:1751286352.671227   15965 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1751286352.671587   15965 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751286352.673351   15965 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.180488 train-accuracy:0.612469 valid-loss:1.144346 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# ...
# I0000 00:00:1751286567.621824   15965 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.724572
# I0000 00:00:1751286567.621866   15965 gradient_boosted_trees.cc:279] Truncates the model to 54 tree(s) i.e. 54  iteration(s).
# I0000 00:00:1751286567.622111   15965 gradient_boosted_trees.cc:341] Final model num-trees:54 valid-loss:0.724572 valid-accuracy:0.863014
# I0000 00:00:1751286567.623334   15964 hyperparameters_optimizer.cc:578] [994/1000] Score: -0.724572 / -0.674996 HParams: fields { name: "min_examples" value { integer: 7 } } fields { name: "categorical_algorithm" value { categorical: "RANDOM" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 32 } } fields { name: "shrinkage" value { real: 0.05 } } fields { name: "num_candidate_attributes_ratio" value { real: 1 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "NONE" } } fields { name: "sparse_oblique_weights" value { categorical: "BINARY" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1751286567.623796   15965 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751286567.623847   15965 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 13 feature(s).
# I0000 00:00:1751286567.624361   15965 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1751286567.624413   15965 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751286567.627735   15965 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.227524 train-accuracy:0.612469 valid-loss:1.201997 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286567.630702   15965 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.138283 train-accuracy:0.734719 valid-loss:1.133094 valid-accuracy:0.794521 [total:0.01s iter:0.00s]
# I0000 00:00:1751286567.809816   15965 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.711664
# I0000 00:00:1751286567.809842   15965 gradient_boosted_trees.cc:279] Truncates the model to 27 tree(s) i.e. 27  iteration(s).
# I0000 00:00:1751286567.810164   15965 gradient_boosted_trees.cc:341] Final model num-trees:27 valid-loss:0.711664 valid-accuracy:0.876712
# I0000 00:00:1751286567.811020   15964 hyperparameters_optimizer.cc:578] [995/1000] Score: -0.711664 / -0.674996 HParams: fields { name: "min_examples" value { integer: 7 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 64 } } fields { name: "shrinkage" value { real: 0.1 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.2 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "MIN_MAX" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1751286567.811621   15965 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751286567.811647   15965 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 13 feature(s).
# I0000 00:00:1751286567.812006   15965 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1751286567.812076   15965 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751286567.816209   15965 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.275675 train-accuracy:0.612469 valid-loss:1.238654 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286567.820628   15965 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.222002 train-accuracy:0.612469 valid-loss:1.194667 valid-accuracy:0.657534 [total:0.01s iter:0.00s]
# I0000 00:00:1751286568.111462   15965 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.768737
# I0000 00:00:1751286568.111488   15965 gradient_boosted_trees.cc:279] Truncates the model to 38 tree(s) i.e. 38  iteration(s).
# I0000 00:00:1751286568.111907   15965 gradient_boosted_trees.cc:341] Final model num-trees:38 valid-loss:0.768737 valid-accuracy:0.863014
# I0000 00:00:1751286568.113453   15964 hyperparameters_optimizer.cc:578] [996/1000] Score: -0.768737 / -0.674996 HParams: fields { name: "min_examples" value { integer: 10 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "LOCAL" } } fields { name: "max_depth" value { integer: 8 } } fields { name: "shrinkage" value { real: 0.05 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.9 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "STANDARD_DEVIATION" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1751286568.114146   15965 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751286568.114197   15965 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 13 feature(s).
# I0000 00:00:1751286568.114576   15965 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1751286568.114626   15965 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751286568.116709   15965 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.314721 train-accuracy:0.612469 valid-loss:1.275716 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286568.118946   15965 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.293479 train-accuracy:0.612469 valid-loss:1.259435 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286568.347253   15965 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.771822
# I0000 00:00:1751286568.347277   15965 gradient_boosted_trees.cc:279] Truncates the model to 108 tree(s) i.e. 108  iteration(s).
# I0000 00:00:1751286568.347528   15965 gradient_boosted_trees.cc:341] Final model num-trees:108 valid-loss:0.771822 valid-accuracy:0.821918
# I0000 00:00:1751286568.350889   15964 hyperparameters_optimizer.cc:578] [997/1000] Score: -0.771822 / -0.674996 HParams: fields { name: "min_examples" value { integer: 10 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 256 } } fields { name: "shrinkage" value { real: 0.02 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.2 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "STANDARD_DEVIATION" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1 } }
# I0000 00:00:1751286568.351339   15965 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751286568.351380   15965 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 13 feature(s).
# I0000 00:00:1751286568.352275   15965 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1751286568.352434   15965 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751286568.356766   15965 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.278781 train-accuracy:0.612469 valid-loss:1.243004 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286568.361083   15965 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.223163 train-accuracy:0.612469 valid-loss:1.201276 valid-accuracy:0.657534 [total:0.01s iter:0.00s]
# I0000 00:00:1751286568.679654   15965 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.785345
# I0000 00:00:1751286568.679679   15965 gradient_boosted_trees.cc:279] Truncates the model to 43 tree(s) i.e. 43  iteration(s).
# I0000 00:00:1751286568.680022   15965 gradient_boosted_trees.cc:341] Final model num-trees:43 valid-loss:0.785345 valid-accuracy:0.835616
# I0000 00:00:1751286568.681295   15964 hyperparameters_optimizer.cc:578] [998/1000] Score: -0.785345 / -0.674996 HParams: fields { name: "min_examples" value { integer: 5 } } fields { name: "categorical_algorithm" value { categorical: "RANDOM" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 128 } } fields { name: "shrinkage" value { real: 0.05 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.9 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "STANDARD_DEVIATION" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1751286568.681994   15965 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751286568.682055   15965 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 13 feature(s).
# I0000 00:00:1751286568.682537   15965 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1751286568.682625   15965 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751286568.683158   15965 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.319054 train-accuracy:0.612469 valid-loss:1.277916 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286568.684012   15965 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.305666 train-accuracy:0.612469 valid-loss:1.262402 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286568.834724   15965 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.74188
# I0000 00:00:1751286568.834747   15965 gradient_boosted_trees.cc:279] Truncates the model to 223 tree(s) i.e. 223  iteration(s).
# I0000 00:00:1751286568.834779   15965 gradient_boosted_trees.cc:341] Final model num-trees:223 valid-loss:0.741880 valid-accuracy:0.835616
# I0000 00:00:1751286568.835312   15964 hyperparameters_optimizer.cc:578] [999/1000] Score: -0.74188 / -0.674996 HParams: fields { name: "min_examples" value { integer: 5 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "LOCAL" } } fields { name: "max_depth" value { integer: 3 } } fields { name: "shrinkage" value { real: 0.02 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.5 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "NONE" } } fields { name: "sparse_oblique_weights" value { categorical: "BINARY" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1 } }
# I0000 00:00:1751286568.835806   15965 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751286568.835822   15965 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 13 feature(s).
# I0000 00:00:1751286568.836184   15965 gradient_boosted_trees.cc:1230] 818 examples used for training and 73 examples used for validation
# I0000 00:00:1751286568.836234   15965 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751286568.839550   15965 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.223469 train-accuracy:0.612469 valid-loss:1.190440 valid-accuracy:0.657534 [total:0.00s iter:0.00s]
# I0000 00:00:1751286568.842775   15965 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.132313 train-accuracy:0.767726 valid-loss:1.118370 valid-accuracy:0.739726 [total:0.01s iter:0.00s]
# Accuracy: 0.8630136847496033 Loss:0.6749962568283081
# I0000 00:00:1751286569.024860   15965 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.769684
# I0000 00:00:1751286569.024886   15965 gradient_boosted_trees.cc:279] Truncates the model to 26 tree(s) i.e. 26  iteration(s).
# I0000 00:00:1751286569.025208   15965 gradient_boosted_trees.cc:341] Final model num-trees:26 valid-loss:0.769684 valid-accuracy:0.835616
# I0000 00:00:1751286569.026294   15964 hyperparameters_optimizer.cc:578] [1000/1000] Score: -0.769684 / -0.674996 HParams: fields { name: "min_examples" value { integer: 5 } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "growing_strategy" value { categorical: "BEST_FIRST_GLOBAL" } } fields { name: "max_num_nodes" value { integer: 64 } } fields { name: "shrinkage" value { real: 0.1 } } fields { name: "num_candidate_attributes_ratio" value { real: 0.5 } } fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_normalization" value { categorical: "NONE" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "sparse_oblique_num_projections_exponent" value { real: 1.5 } }
# I0000 00:00:1751286569.027325   15964 hyperparameters_optimizer.cc:219] Best hyperparameters:
# fields {
#   name: "min_examples"
#   value {
#     integer: 5
#   }
# }
# fields {
#   name: "categorical_algorithm"
#   value {
#     categorical: "RANDOM"
#   }
# }
# fields {
#   name: "growing_strategy"
#   value {
#     categorical: "BEST_FIRST_GLOBAL"
#   }
# }
# fields {
#   name: "max_num_nodes"
#   value {
#     integer: 256
#   }
# }
# fields {
#   name: "shrinkage"
#   value {
#     real: 0.1
#   }
# }
# fields {
#   name: "num_candidate_attributes_ratio"
#   value {
#     real: 0.2
#   }
# }
# fields {
#   name: "split_axis"
#   value {
#     categorical: "SPARSE_OBLIQUE"
#   }
# }
# fields {
#   name: "sparse_oblique_normalization"
#   value {
#     categorical: "STANDARD_DEVIATION"
#   }
# }
# fields {
#   name: "sparse_oblique_weights"
#   value {
#     categorical: "CONTINUOUS"
#   }
# }
# fields {
#   name: "sparse_oblique_num_projections_exponent"
#   value {
#     real: 1
#   }
# }
#
# I0000 00:00:1751286569.030872   15964 kernel.cc:926] Export model in log directory: /tmp/tmp4s1jmnoi with prefix de276e70f92748d7
# I0000 00:00:1751286569.037434   15964 kernel.cc:944] Save model in resources
# I0000 00:00:1751286569.039297   13176 abstract_model.cc:921] Model self evaluation:
# Task: CLASSIFICATION
# Label: __LABEL
# Loss (BINOMIAL_LOG_LIKELIHOOD): 0.674996
#
# Accuracy: 0.863014  CI95[W][0 1]
# ErrorRate: : 0.136986
#
#
# Confusion Table:
# truth\prediction
#     1   2
# 1  42   6
# 2   4  21
# Total: 73
#
#
# 2025-06-30 21:29:29.053041: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1206] Loading model from path /tmp/tmp4s1jmnoi/model/ with prefix de276e70f92748d7
# I0000 00:00:1751286569.062847   13176 decision_forest.cc:808] Model loaded with 30 root(s), 2236 node(s), and 12 input feature(s).
# I0000 00:00:1751286569.062865   13176 abstract_model.cc:1439] Engine "GradientBoostedTreesGeneric" built
# 2025-06-30 21:29:29.062873: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1035] Use fast generic engine

# %%
def prediction_to_kaggle_format(model, threshold=0.5):
    proba_survive = model.predict(serving_ds, verbose=0)[:,0]
    return pd.DataFrame({
        "PassengerId": serving_df["PassengerId"],
        "Survived": (proba_survive >= threshold).astype(int)
    })

def make_submission(kaggle_predictions):
    path="submission.csv"
    kaggle_predictions.to_csv(path, index=False)
    print(f"Submission exported to {path}")
    
kaggle_predictions = prediction_to_kaggle_format(tuned_model)
make_submission(kaggle_predictions)
# Out:
# Submission exported to submission.csv

# %%
predictions = None
num_predictions = 0

for i in range(100):
    print(f"i:{i}")
    # Possible models: GradientBoostedTreesModel or RandomForestModel
    model = tfdf.keras.GradientBoostedTreesModel(
        verbose=0, # Very few logs
        features=[tfdf.keras.FeatureUsage(name=n) for n in input_features],
        exclude_non_specified_features=True, # Only use the features in "features"

        #min_examples=1,
        #categorical_algorithm="RANDOM",
        ##max_depth=4,
        #shrinkage=0.05,
        ##num_candidate_attributes_ratio=0.2,
        #split_axis="SPARSE_OBLIQUE",
        #sparse_oblique_normalization="MIN_MAX",
        #sparse_oblique_num_projections_exponent=2.0,
        #num_trees=2000,
        ##validation_ratio=0.0,
        random_seed=i,
        honest=True,
    )
    model.fit(train_ds)
    
    sub_predictions = model.predict(serving_ds, verbose=0)[:,0]
    if predictions is None:
        predictions = sub_predictions
    else:
        predictions += sub_predictions
    num_predictions += 1

predictions/=num_predictions

kaggle_predictions = pd.DataFrame({
        "PassengerId": serving_df["PassengerId"],
        "Survived": (predictions >= 0.5).astype(int)
    })

make_submission(kaggle_predictions)
# Out:
# i:0
# W0000 00:00:1751287161.447532   13176 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287161.447550   13176 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287161.447569   13176 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1751287161.676927   13176 kernel.cc:782] Start Yggdrasil model training
# I0000 00:00:1751287161.676944   13176 kernel.cc:783] Collect training examples
# I0000 00:00:1751287161.676950   13176 kernel.cc:795] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# column_guides {
#   column_name_pattern: "^Pclass$"
# }
# column_guides {
#   column_name_pattern: "^Name$"
# }
# column_guides {
#   column_name_pattern: "^Sex$"
# }
# column_guides {
#   column_name_pattern: "^Age$"
# }
# column_guides {
#   column_name_pattern: "^SibSp$"
# }
# column_guides {
#   column_name_pattern: "^Parch$"
# }
# column_guides {
#   column_name_pattern: "^Fare$"
# }
# column_guides {
#   column_name_pattern: "^Cabin$"
# }
# column_guides {
#   column_name_pattern: "^Embarked$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_number$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_item$"
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: true
# detect_numerical_as_discretized_numerical: false
#
# I0000 00:00:1751287161.677184   13176 kernel.cc:401] Number of batches: 1
# I0000 00:00:1751287161.677192   13176 kernel.cc:402] Number of examples: 891
# I0000 00:00:1751287161.678067   13176 data_spec_inference.cc:354] 147 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Cabin (0 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287161.678353   13176 data_spec_inference.cc:354] 1441 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Name (85 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287161.678535   13176 data_spec_inference.cc:354] 28 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_item (16 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287161.678675   13176 data_spec_inference.cc:354] 671 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_number (8 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287161.679036   13176 kernel.cc:802] Training dataset:
# Number of records: 891
# Number of columns: 12
#
# Number of columns by type:
# 	CATEGORICAL: 6 (50%)
# 	NUMERICAL: 5 (41.6667%)
# 	CATEGORICAL_SET: 1 (8.33333%)
#
# Columns:
#
# CATEGORICAL: 6 (50%)
# 	1: "Cabin" CATEGORICAL num-nas:687 (77.1044%) has-dict vocab-size:1 num-oods:204 (100%)
# 	2: "Embarked" CATEGORICAL num-nas:2 (0.224467%) has-dict vocab-size:4 zero-ood-items most-frequent:"S" 644 (72.4409%)
# 	7: "Sex" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"male" 577 (64.7587%)
# 	9: "Ticket_item" CATEGORICAL has-dict vocab-size:17 num-oods:46 (5.16274%) most-frequent:"NONE" 665 (74.6352%)
# 	10: "Ticket_number" CATEGORICAL has-dict vocab-size:9 num-oods:842 (94.5006%) most-frequent:"<OOD>" 842 (94.5006%)
# 	11: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 5 (41.6667%)
# 	0: "Age" NUMERICAL num-nas:177 (19.8653%) mean:29.6991 min:0.42 max:80 sd:14.5163
# 	3: "Fare" NUMERICAL mean:32.2042 min:0 max:512.329 sd:49.6655
# 	5: "Parch" NUMERICAL mean:0.381594 min:0 max:6 sd:0.805605
# 	6: "Pclass" NUMERICAL mean:2.30864 min:1 max:3 sd:0.835602
# 	8: "SibSp" NUMERICAL mean:0.523008 min:0 max:8 sd:1.10212
#
# CATEGORICAL_SET: 1 (8.33333%)
# 	4: "Name" CATEGORICAL_SET has-dict vocab-size:86 num-oods:1932 (216.835%) most-frequent:"<OOD>" 1932 (216.835%)
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1751287161.679059   13176 kernel.cc:818] Configure learner
# W0000 00:00:1751287161.679326   13176 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287161.679332   13176 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287161.679334   13176 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1751287161.679367   13176 kernel.cc:831] Training config:
# learner: "GRADIENT_BOOSTED_TREES"
# features: "^Age$"
# features: "^Cabin$"
# features: "^Embarked$"
# features: "^Fare$"
# features: "^Name$"
# features: "^Parch$"
# features: "^Pclass$"
# features: "^Sex$"
# features: "^SibSp$"
# features: "^Ticket_item$"
# features: "^Ticket_number$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# random_seed: 0
# metadata {
#   framework: "TF Keras"
# }
# pure_serving_model: false
# [yggdrasil_decision_forests.model.gradient_boosted_trees.proto.gradient_boosted_trees_config] {
#   num_trees: 300
#   decision_tree {
#     max_depth: 6
#     min_examples: 5
#     in_split_min_examples_check: true
#     keep_non_leaf_label_distribution: true
#     num_candidate_attributes: -1
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#     uplift {
#       min_examples_in_treatment: 5
#       split_score: KULLBACK_LEIBLER
#     }
#     honest {
#       ratio_leaf_examples: 0.5
#       fixed_separation: false
#     }
#     numerical_vector_sequence {
#       max_num_test_examples: 1000
#       num_random_selected_anchors: 100
#     }
#   }
#   shrinkage: 0.1
#   loss: DEFAULT
#   validation_set_ratio: 0.1
#   validation_interval_in_trees: 1
#   early_stopping: VALIDATION_LOSS_INCREASE
#   early_stopping_num_trees_look_ahead: 30
#   l2_regularization: 0
#   lambda_loss: 1
#   mart {
#   }
#   adapt_subsample_for_maximum_training_duration: false
#   l1_regularization: 0
#   use_hessian_gain: false
#   l2_regularization_categorical: 1
#   xe_ndcg {
#     ndcg_truncation: 5
#   }
#   stochastic_gradient_boosting {
#     ratio: 1
#   }
#   apply_link_function: true
#   compute_permutation_variable_importance: false
#   early_stopping_initial_iteration: 10
# }
#
# I0000 00:00:1751287161.679428   13176 kernel.cc:834] Deployment config:
# cache_path: "/tmp/tmpobsoc_kk/working_cache"
# num_threads: 8
# try_resume_training: true
#
# I0000 00:00:1751287161.679535  102083 kernel.cc:895] Train model
# I0000 00:00:1751287161.679612  102083 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751287161.679620  102083 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 11 feature(s).
# I0000 00:00:1751287161.680027  102083 gradient_boosted_trees.cc:1230] 797 examples used for training and 94 examples used for validation
# I0000 00:00:1751287161.680466  102083 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751287161.682209  102083 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.246781 train-accuracy:0.613551 valid-loss:1.237893 valid-accuracy:0.638298 [total:0.00s iter:0.00s]
# I0000 00:00:1751287161.683797  102083 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.175101 train-accuracy:0.776662 valid-loss:1.171704 valid-accuracy:0.744681 [total:0.00s iter:0.00s]
# I0000 00:00:1751287161.685336  102083 gradient_boosted_trees.cc:1634] Train tree 3/300 train-loss:1.115419 train-accuracy:0.786700 valid-loss:1.123651 valid-accuracy:0.765957 [total:0.00s iter:0.00s]
# I0000 00:00:1751287161.760295  102083 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.880514
# I0000 00:00:1751287161.760317  102083 gradient_boosted_trees.cc:1669] Create final snapshot of the model at iteration 52
# I0000 00:00:1751287161.763703  102083 gradient_boosted_trees.cc:279] Truncates the model to 23 tree(s) i.e. 23  iteration(s).
# I0000 00:00:1751287161.763850  102083 gradient_boosted_trees.cc:341] Final model num-trees:23 valid-loss:0.880514 valid-accuracy:0.797872
# I0000 00:00:1751287161.764166  102083 kernel.cc:926] Export model in log directory: /tmp/tmpobsoc_kk with prefix 97cc9398d81d420d
# I0000 00:00:1751287161.764794  102083 kernel.cc:944] Save model in resources
# I0000 00:00:1751287161.766013   13176 abstract_model.cc:921] Model self evaluation:
# Task: CLASSIFICATION
# Label: __LABEL
# Loss (BINOMIAL_LOG_LIKELIHOOD): 0.880514
#
# Accuracy: 0.797872  CI95[W][0 1]
# ErrorRate: : 0.202128
#
#
# Confusion Table:
# truth\prediction
#     1   2
# 1  52   8
# 2  11  23
# Total: 94
#
#
# 2025-06-30 21:39:21.777445: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1206] Loading model from path /tmp/tmpobsoc_kk/model/ with prefix 97cc9398d81d420d
# I0000 00:00:1751287161.779891   13176 quick_scorer_extended.cc:927] The binary was compiled without AVX2 support, but your CPU supports it. Enable it for faster model inference.
# I0000 00:00:1751287161.780128   13176 abstract_model.cc:1439] Engine "GradientBoostedTreesQuickScorerExtended" built
# 2025-06-30 21:39:21.780160: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1035] Use fast generic engine
# i:1
# W0000 00:00:1751287162.019181   13176 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287162.019199   13176 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287162.019202   13176 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1751287162.207080   13176 kernel.cc:782] Start Yggdrasil model training
# I0000 00:00:1751287162.207104   13176 kernel.cc:783] Collect training examples
# I0000 00:00:1751287162.207130   13176 kernel.cc:795] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# column_guides {
#   column_name_pattern: "^Pclass$"
# }
# column_guides {
#   column_name_pattern: "^Name$"
# }
# column_guides {
#   column_name_pattern: "^Sex$"
# }
# column_guides {
#   column_name_pattern: "^Age$"
# }
# column_guides {
#   column_name_pattern: "^SibSp$"
# }
# column_guides {
#   column_name_pattern: "^Parch$"
# }
# column_guides {
#   column_name_pattern: "^Fare$"
# }
# column_guides {
#   column_name_pattern: "^Cabin$"
# }
# column_guides {
#   column_name_pattern: "^Embarked$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_number$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_item$"
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: true
# detect_numerical_as_discretized_numerical: false
#
# I0000 00:00:1751287162.207606   13176 kernel.cc:401] Number of batches: 1
# I0000 00:00:1751287162.207616   13176 kernel.cc:402] Number of examples: 891
# I0000 00:00:1751287162.208728   13176 data_spec_inference.cc:354] 147 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Cabin (0 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287162.209090   13176 data_spec_inference.cc:354] 1441 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Name (85 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287162.209244   13176 data_spec_inference.cc:354] 28 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_item (16 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287162.209432   13176 data_spec_inference.cc:354] 671 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_number (8 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287162.209851   13176 kernel.cc:802] Training dataset:
# Number of records: 891
# Number of columns: 12
#
# Number of columns by type:
# 	CATEGORICAL: 6 (50%)
# 	NUMERICAL: 5 (41.6667%)
# 	CATEGORICAL_SET: 1 (8.33333%)
#
# Columns:
#
# CATEGORICAL: 6 (50%)
# 	1: "Cabin" CATEGORICAL num-nas:687 (77.1044%) has-dict vocab-size:1 num-oods:204 (100%)
# 	2: "Embarked" CATEGORICAL num-nas:2 (0.224467%) has-dict vocab-size:4 zero-ood-items most-frequent:"S" 644 (72.4409%)
# 	7: "Sex" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"male" 577 (64.7587%)
# 	9: "Ticket_item" CATEGORICAL has-dict vocab-size:17 num-oods:46 (5.16274%) most-frequent:"NONE" 665 (74.6352%)
# 	10: "Ticket_number" CATEGORICAL has-dict vocab-size:9 num-oods:842 (94.5006%) most-frequent:"<OOD>" 842 (94.5006%)
# 	11: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 5 (41.6667%)
# 	0: "Age" NUMERICAL num-nas:177 (19.8653%) mean:29.6991 min:0.42 max:80 sd:14.5163
# 	3: "Fare" NUMERICAL mean:32.2042 min:0 max:512.329 sd:49.6655
# 	5: "Parch" NUMERICAL mean:0.381594 min:0 max:6 sd:0.805605
# 	6: "Pclass" NUMERICAL mean:2.30864 min:1 max:3 sd:0.835602
# 	8: "SibSp" NUMERICAL mean:0.523008 min:0 max:8 sd:1.10212
#
# CATEGORICAL_SET: 1 (8.33333%)
# 	4: "Name" CATEGORICAL_SET has-dict vocab-size:86 num-oods:1932 (216.835%) most-frequent:"<OOD>" 1932 (216.835%)
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1751287162.209895   13176 kernel.cc:818] Configure learner
# W0000 00:00:1751287162.210134   13176 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287162.210142   13176 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287162.210147   13176 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1751287162.210182   13176 kernel.cc:831] Training config:
# learner: "GRADIENT_BOOSTED_TREES"
# features: "^Age$"
# features: "^Cabin$"
# features: "^Embarked$"
# features: "^Fare$"
# features: "^Name$"
# features: "^Parch$"
# features: "^Pclass$"
# features: "^Sex$"
# features: "^SibSp$"
# features: "^Ticket_item$"
# features: "^Ticket_number$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# random_seed: 1
# metadata {
#   framework: "TF Keras"
# }
# pure_serving_model: false
# [yggdrasil_decision_forests.model.gradient_boosted_trees.proto.gradient_boosted_trees_config] {
#   num_trees: 300
#   decision_tree {
#     max_depth: 6
#     min_examples: 5
#     in_split_min_examples_check: true
#     keep_non_leaf_label_distribution: true
#     num_candidate_attributes: -1
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#     uplift {
#       min_examples_in_treatment: 5
#       split_score: KULLBACK_LEIBLER
#     }
#     honest {
#       ratio_leaf_examples: 0.5
#       fixed_separation: false
#     }
#     numerical_vector_sequence {
#       max_num_test_examples: 1000
#       num_random_selected_anchors: 100
#     }
#   }
#   shrinkage: 0.1
#   loss: DEFAULT
#   validation_set_ratio: 0.1
#   validation_interval_in_trees: 1
#   early_stopping: VALIDATION_LOSS_INCREASE
#   early_stopping_num_trees_look_ahead: 30
#   l2_regularization: 0
#   lambda_loss: 1
#   mart {
#   }
#   adapt_subsample_for_maximum_training_duration: false
#   l1_regularization: 0
#   use_hessian_gain: false
#   l2_regularization_categorical: 1
#   xe_ndcg {
#     ndcg_truncation: 5
#   }
#   stochastic_gradient_boosting {
#     ratio: 1
#   }
#   apply_link_function: true
#   compute_permutation_variable_importance: false
#   early_stopping_initial_iteration: 10
# }
#
# I0000 00:00:1751287162.210248   13176 kernel.cc:834] Deployment config:
# cache_path: "/tmp/tmpcqj5_fwl/working_cache"
# num_threads: 8
# try_resume_training: true
#
# I0000 00:00:1751287162.210376  102573 kernel.cc:895] Train model
# I0000 00:00:1751287162.210470  102573 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751287162.210479  102573 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 11 feature(s).
# I0000 00:00:1751287162.210891  102573 gradient_boosted_trees.cc:1230] 783 examples used for training and 108 examples used for validation
# I0000 00:00:1751287162.211447  102573 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751287162.213354  102573 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.237646 train-accuracy:0.610473 valid-loss:1.199537 valid-accuracy:0.657407 [total:0.00s iter:0.00s]
# I0000 00:00:1751287162.214826  102573 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.171441 train-accuracy:0.724138 valid-loss:1.134860 valid-accuracy:0.796296 [total:0.00s iter:0.00s]
# I0000 00:00:1751287162.466710  102573 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.691023
# I0000 00:00:1751287162.466733  102573 gradient_boosted_trees.cc:1669] Create final snapshot of the model at iteration 170
# I0000 00:00:1751287162.475400  102573 gradient_boosted_trees.cc:279] Truncates the model to 141 tree(s) i.e. 141  iteration(s).
# I0000 00:00:1751287162.475783  102573 gradient_boosted_trees.cc:341] Final model num-trees:141 valid-loss:0.691023 valid-accuracy:0.861111
# I0000 00:00:1751287162.477536  102573 kernel.cc:926] Export model in log directory: /tmp/tmpcqj5_fwl with prefix f49acfcb5b1b4f1e
# I0000 00:00:1751287162.480622  102573 kernel.cc:944] Save model in resources
# I0000 00:00:1751287162.482060   13176 abstract_model.cc:921] Model self evaluation:
# Task: CLASSIFICATION
# Label: __LABEL
# Loss (BINOMIAL_LOG_LIKELIHOOD): 0.691023
#
# Accuracy: 0.861111  CI95[W][0 1]
# ErrorRate: : 0.138889
#
#
# Confusion Table:
# truth\prediction
#     1   2
# 1  62   9
# 2   6  31
# Total: 108
#
#
# 2025-06-30 21:39:22.492001: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1206] Loading model from path /tmp/tmpcqj5_fwl/model/ with prefix f49acfcb5b1b4f1e
# 2025-06-30 21:39:22.504008: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1035] Use fast generic engine
# i:2
# W0000 00:00:1751287162.750326   13176 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287162.750345   13176 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287162.750347   13176 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1751287162.958490   13176 kernel.cc:782] Start Yggdrasil model training
# I0000 00:00:1751287162.958511   13176 kernel.cc:783] Collect training examples
# I0000 00:00:1751287162.958529   13176 kernel.cc:795] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# column_guides {
#   column_name_pattern: "^Pclass$"
# }
# column_guides {
#   column_name_pattern: "^Name$"
# }
# column_guides {
#   column_name_pattern: "^Sex$"
# }
# column_guides {
#   column_name_pattern: "^Age$"
# }
# column_guides {
#   column_name_pattern: "^SibSp$"
# }
# column_guides {
#   column_name_pattern: "^Parch$"
# }
# column_guides {
#   column_name_pattern: "^Fare$"
# }
# column_guides {
#   column_name_pattern: "^Cabin$"
# }
# column_guides {
#   column_name_pattern: "^Embarked$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_number$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_item$"
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: true
# detect_numerical_as_discretized_numerical: false
#
# I0000 00:00:1751287162.958919   13176 kernel.cc:401] Number of batches: 1
# I0000 00:00:1751287162.958929   13176 kernel.cc:402] Number of examples: 891
# I0000 00:00:1751287162.959895   13176 data_spec_inference.cc:354] 147 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Cabin (0 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287162.960611   13176 data_spec_inference.cc:354] 1441 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Name (85 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287162.960877   13176 data_spec_inference.cc:354] 28 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_item (16 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287162.961135   13176 data_spec_inference.cc:354] 671 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_number (8 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287162.961946   13176 kernel.cc:802] Training dataset:
# Number of records: 891
# Number of columns: 12
#
# Number of columns by type:
# 	CATEGORICAL: 6 (50%)
# 	NUMERICAL: 5 (41.6667%)
# 	CATEGORICAL_SET: 1 (8.33333%)
#
# Columns:
#
# CATEGORICAL: 6 (50%)
# 	1: "Cabin" CATEGORICAL num-nas:687 (77.1044%) has-dict vocab-size:1 num-oods:204 (100%)
# 	2: "Embarked" CATEGORICAL num-nas:2 (0.224467%) has-dict vocab-size:4 zero-ood-items most-frequent:"S" 644 (72.4409%)
# 	7: "Sex" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"male" 577 (64.7587%)
# 	9: "Ticket_item" CATEGORICAL has-dict vocab-size:17 num-oods:46 (5.16274%) most-frequent:"NONE" 665 (74.6352%)
# 	10: "Ticket_number" CATEGORICAL has-dict vocab-size:9 num-oods:842 (94.5006%) most-frequent:"<OOD>" 842 (94.5006%)
# 	11: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 5 (41.6667%)
# 	0: "Age" NUMERICAL num-nas:177 (19.8653%) mean:29.6991 min:0.42 max:80 sd:14.5163
# 	3: "Fare" NUMERICAL mean:32.2042 min:0 max:512.329 sd:49.6655
# 	5: "Parch" NUMERICAL mean:0.381594 min:0 max:6 sd:0.805605
# 	6: "Pclass" NUMERICAL mean:2.30864 min:1 max:3 sd:0.835602
# 	8: "SibSp" NUMERICAL mean:0.523008 min:0 max:8 sd:1.10212
#
# CATEGORICAL_SET: 1 (8.33333%)
# 	4: "Name" CATEGORICAL_SET has-dict vocab-size:86 num-oods:1932 (216.835%) most-frequent:"<OOD>" 1932 (216.835%)
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1751287162.961974   13176 kernel.cc:818] Configure learner
# W0000 00:00:1751287162.962237   13176 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287162.962245   13176 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287162.962249   13176 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1751287162.962344   13176 kernel.cc:831] Training config:
# learner: "GRADIENT_BOOSTED_TREES"
# features: "^Age$"
# features: "^Cabin$"
# features: "^Embarked$"
# features: "^Fare$"
# features: "^Name$"
# features: "^Parch$"
# features: "^Pclass$"
# features: "^Sex$"
# features: "^SibSp$"
# features: "^Ticket_item$"
# features: "^Ticket_number$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# random_seed: 2
# metadata {
#   framework: "TF Keras"
# }
# pure_serving_model: false
# [yggdrasil_decision_forests.model.gradient_boosted_trees.proto.gradient_boosted_trees_config] {
#   num_trees: 300
#   decision_tree {
#     max_depth: 6
#     min_examples: 5
#     in_split_min_examples_check: true
#     keep_non_leaf_label_distribution: true
#     num_candidate_attributes: -1
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#     uplift {
#       min_examples_in_treatment: 5
#       split_score: KULLBACK_LEIBLER
#     }
#     honest {
#       ratio_leaf_examples: 0.5
#       fixed_separation: false
#     }
#     numerical_vector_sequence {
#       max_num_test_examples: 1000
#       num_random_selected_anchors: 100
#     }
#   }
#   shrinkage: 0.1
#   loss: DEFAULT
#   validation_set_ratio: 0.1
#   validation_interval_in_trees: 1
#   early_stopping: VALIDATION_LOSS_INCREASE
#   early_stopping_num_trees_look_ahead: 30
#   l2_regularization: 0
#   lambda_loss: 1
#   mart {
#   }
#   adapt_subsample_for_maximum_training_duration: false
#   l1_regularization: 0
#   use_hessian_gain: false
#   l2_regularization_categorical: 1
#   xe_ndcg {
#     ndcg_truncation: 5
#   }
#   stochastic_gradient_boosting {
#     ratio: 1
#   }
#   apply_link_function: true
#   compute_permutation_variable_importance: false
#   early_stopping_initial_iteration: 10
# }
#
# I0000 00:00:1751287162.962441   13176 kernel.cc:834] Deployment config:
# cache_path: "/tmp/tmpbgvdubqm/working_cache"
# num_threads: 8
# try_resume_training: true
#
# I0000 00:00:1751287162.962535  104006 kernel.cc:895] Train model
# I0000 00:00:1751287162.962635  104006 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751287162.962646  104006 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 11 feature(s).
# I0000 00:00:1751287162.963141  104006 gradient_boosted_trees.cc:1230] 804 examples used for training and 87 examples used for validation
# I0000 00:00:1751287162.963636  104006 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751287162.965589  104006 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.219599 train-accuracy:0.628109 valid-loss:1.332006 valid-accuracy:0.505747 [total:0.00s iter:0.00s]
# I0000 00:00:1751287162.967128  104006 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.155824 train-accuracy:0.628109 valid-loss:1.252138 valid-accuracy:0.505747 [total:0.00s iter:0.00s]
# I0000 00:00:1751287163.047904  104006 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.818454
# I0000 00:00:1751287163.047927  104006 gradient_boosted_trees.cc:1669] Create final snapshot of the model at iteration 55
# I0000 00:00:1751287163.051403  104006 gradient_boosted_trees.cc:279] Truncates the model to 26 tree(s) i.e. 26  iteration(s).
# I0000 00:00:1751287163.051671  104006 gradient_boosted_trees.cc:341] Final model num-trees:26 valid-loss:0.818454 valid-accuracy:0.804598
# I0000 00:00:1751287163.052329  104006 kernel.cc:926] Export model in log directory: /tmp/tmpbgvdubqm with prefix 2ae18c470f1648d4
# I0000 00:00:1751287163.054172  104006 kernel.cc:944] Save model in resources
# I0000 00:00:1751287163.055138   13176 abstract_model.cc:921] Model self evaluation:
# Task: CLASSIFICATION
# Label: __LABEL
# Loss (BINOMIAL_LOG_LIKELIHOOD): 0.818454
#
# Accuracy: 0.804598  CI95[W][0 1]
# ErrorRate: : 0.195402
#
#
# Confusion Table:
# truth\prediction
#     1   2
# 1  41   3
# 2  14  29
# Total: 87
#
#
# 2025-06-30 21:39:23.064046: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1206] Loading model from path /tmp/tmpbgvdubqm/model/ with prefix 2ae18c470f1648d4
# 2025-06-30 21:39:23.066522: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1035] Use fast generic engine
# i:3
# W0000 00:00:1751287163.293037   13176 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287163.293059   13176 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287163.293061   13176 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1751287163.482619   13176 kernel.cc:782] Start Yggdrasil model training
# I0000 00:00:1751287163.482637   13176 kernel.cc:783] Collect training examples
# I0000 00:00:1751287163.482642   13176 kernel.cc:795] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# column_guides {
#   column_name_pattern: "^Pclass$"
# }
# column_guides {
#   column_name_pattern: "^Name$"
# }
# column_guides {
#   column_name_pattern: "^Sex$"
# }
# column_guides {
#   column_name_pattern: "^Age$"
# }
# column_guides {
#   column_name_pattern: "^SibSp$"
# }
# column_guides {
#   column_name_pattern: "^Parch$"
# }
# column_guides {
#   column_name_pattern: "^Fare$"
# }
# column_guides {
#   column_name_pattern: "^Cabin$"
# }
# column_guides {
#   column_name_pattern: "^Embarked$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_number$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_item$"
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: true
# detect_numerical_as_discretized_numerical: false
#
# I0000 00:00:1751287163.482812   13176 kernel.cc:401] Number of batches: 1
# I0000 00:00:1751287163.482816   13176 kernel.cc:402] Number of examples: 891
# I0000 00:00:1751287163.483353   13176 data_spec_inference.cc:354] 147 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Cabin (0 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287163.483628   13176 data_spec_inference.cc:354] 1441 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Name (85 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287163.483732   13176 data_spec_inference.cc:354] 28 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_item (16 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287163.483850   13176 data_spec_inference.cc:354] 671 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_number (8 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287163.484180   13176 kernel.cc:802] Training dataset:
# Number of records: 891
# Number of columns: 12
#
# Number of columns by type:
# 	CATEGORICAL: 6 (50%)
# 	NUMERICAL: 5 (41.6667%)
# 	CATEGORICAL_SET: 1 (8.33333%)
#
# Columns:
#
# CATEGORICAL: 6 (50%)
# 	1: "Cabin" CATEGORICAL num-nas:687 (77.1044%) has-dict vocab-size:1 num-oods:204 (100%)
# 	2: "Embarked" CATEGORICAL num-nas:2 (0.224467%) has-dict vocab-size:4 zero-ood-items most-frequent:"S" 644 (72.4409%)
# 	7: "Sex" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"male" 577 (64.7587%)
# 	9: "Ticket_item" CATEGORICAL has-dict vocab-size:17 num-oods:46 (5.16274%) most-frequent:"NONE" 665 (74.6352%)
# 	10: "Ticket_number" CATEGORICAL has-dict vocab-size:9 num-oods:842 (94.5006%) most-frequent:"<OOD>" 842 (94.5006%)
# 	11: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 5 (41.6667%)
# 	0: "Age" NUMERICAL num-nas:177 (19.8653%) mean:29.6991 min:0.42 max:80 sd:14.5163
# 	3: "Fare" NUMERICAL mean:32.2042 min:0 max:512.329 sd:49.6655
# 	5: "Parch" NUMERICAL mean:0.381594 min:0 max:6 sd:0.805605
# 	6: "Pclass" NUMERICAL mean:2.30864 min:1 max:3 sd:0.835602
# 	8: "SibSp" NUMERICAL mean:0.523008 min:0 max:8 sd:1.10212
#
# CATEGORICAL_SET: 1 (8.33333%)
# 	4: "Name" CATEGORICAL_SET has-dict vocab-size:86 num-oods:1932 (216.835%) most-frequent:"<OOD>" 1932 (216.835%)
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1751287163.484200   13176 kernel.cc:818] Configure learner
# W0000 00:00:1751287163.484344   13176 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287163.484349   13176 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287163.484350   13176 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1751287163.484377   13176 kernel.cc:831] Training config:
# learner: "GRADIENT_BOOSTED_TREES"
# features: "^Age$"
# features: "^Cabin$"
# features: "^Embarked$"
# features: "^Fare$"
# features: "^Name$"
# features: "^Parch$"
# features: "^Pclass$"
# features: "^Sex$"
# features: "^SibSp$"
# features: "^Ticket_item$"
# features: "^Ticket_number$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# random_seed: 3
# metadata {
#   framework: "TF Keras"
# }
# pure_serving_model: false
# [yggdrasil_decision_forests.model.gradient_boosted_trees.proto.gradient_boosted_trees_config] {
#   num_trees: 300
#   decision_tree {
#     max_depth: 6
#     min_examples: 5
#     in_split_min_examples_check: true
#     keep_non_leaf_label_distribution: true
#     num_candidate_attributes: -1
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#     uplift {
#       min_examples_in_treatment: 5
#       split_score: KULLBACK_LEIBLER
#     }
#     honest {
#       ratio_leaf_examples: 0.5
#       fixed_separation: false
#     }
#     numerical_vector_sequence {
#       max_num_test_examples: 1000
#       num_random_selected_anchors: 100
#     }
#   }
#   shrinkage: 0.1
#   loss: DEFAULT
#   validation_set_ratio: 0.1
#   validation_interval_in_trees: 1
#   early_stopping: VALIDATION_LOSS_INCREASE
#   early_stopping_num_trees_look_ahead: 30
#   l2_regularization: 0
#   lambda_loss: 1
#   mart {
#   }
#   adapt_subsample_for_maximum_training_duration: false
#   l1_regularization: 0
#   use_hessian_gain: false
#   l2_regularization_categorical: 1
#   xe_ndcg {
#     ndcg_truncation: 5
#   }
#   stochastic_gradient_boosting {
#     ratio: 1
#   }
#   apply_link_function: true
#   compute_permutation_variable_importance: false
#   early_stopping_initial_iteration: 10
# }
#
# I0000 00:00:1751287163.484438   13176 kernel.cc:834] Deployment config:
# cache_path: "/tmp/tmpx_s8u8ys/working_cache"
# num_threads: 8
# try_resume_training: true
#
# I0000 00:00:1751287163.484539  104520 kernel.cc:895] Train model
# I0000 00:00:1751287163.484615  104520 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751287163.484621  104520 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 11 feature(s).
# I0000 00:00:1751287163.485020  104520 gradient_boosted_trees.cc:1230] 795 examples used for training and 96 examples used for validation
# I0000 00:00:1751287163.485412  104520 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751287163.487339  104520 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.220683 train-accuracy:0.623899 valid-loss:1.300028 valid-accuracy:0.552083 [total:0.00s iter:0.00s]
# I0000 00:00:1751287163.488950  104520 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.150915 train-accuracy:0.623899 valid-loss:1.233753 valid-accuracy:0.552083 [total:0.00s iter:0.00s]
# I0000 00:00:1751287163.816537  104520 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.766689
# I0000 00:00:1751287163.816560  104520 gradient_boosted_trees.cc:1669] Create final snapshot of the model at iteration 221
# I0000 00:00:1751287163.821383  104520 gradient_boosted_trees.cc:279] Truncates the model to 192 tree(s) i.e. 192  iteration(s).
# I0000 00:00:1751287163.821592  104520 gradient_boosted_trees.cc:341] Final model num-trees:192 valid-loss:0.766689 valid-accuracy:0.822917
# I0000 00:00:1751287163.823068  104520 kernel.cc:926] Export model in log directory: /tmp/tmpx_s8u8ys with prefix bca5b04e00d34302
# I0000 00:00:1751287163.829466  104520 kernel.cc:944] Save model in resources
# I0000 00:00:1751287163.830836   13176 abstract_model.cc:921] Model self evaluation:
# Task: CLASSIFICATION
# Label: __LABEL
# Loss (BINOMIAL_LOG_LIKELIHOOD): 0.766689
#
# Accuracy: 0.822917  CI95[W][0 1]
# ErrorRate: : 0.177083
#
#
# Confusion Table:
# truth\prediction
#     1   2
# 1  51   2
# 2  15  28
# Total: 96
#
#
# 2025-06-30 21:39:23.841606: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1206] Loading model from path /tmp/tmpx_s8u8ys/model/ with prefix bca5b04e00d34302
# 2025-06-30 21:39:23.855428: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1035] Use fast generic engine
# i:4
# W0000 00:00:1751287164.088428   13176 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287164.088446   13176 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287164.088448   13176 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1751287164.274261   13176 kernel.cc:782] Start Yggdrasil model training
# I0000 00:00:1751287164.274281   13176 kernel.cc:783] Collect training examples
# I0000 00:00:1751287164.274291   13176 kernel.cc:795] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# column_guides {
#   column_name_pattern: "^Pclass$"
# }
# column_guides {
#   column_name_pattern: "^Name$"
# }
# column_guides {
#   column_name_pattern: "^Sex$"
# }
# column_guides {
#   column_name_pattern: "^Age$"
# }
# column_guides {
#   column_name_pattern: "^SibSp$"
# }
# column_guides {
#   column_name_pattern: "^Parch$"
# }
# column_guides {
#   column_name_pattern: "^Fare$"
# }
# column_guides {
#   column_name_pattern: "^Cabin$"
# }
# column_guides {
#   column_name_pattern: "^Embarked$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_number$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_item$"
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: true
# detect_numerical_as_discretized_numerical: false
#
# I0000 00:00:1751287164.274461   13176 kernel.cc:401] Number of batches: 1
# I0000 00:00:1751287164.274468   13176 kernel.cc:402] Number of examples: 891
# I0000 00:00:1751287164.274959   13176 data_spec_inference.cc:354] 147 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Cabin (0 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287164.275283   13176 data_spec_inference.cc:354] 1441 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Name (85 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287164.275475   13176 data_spec_inference.cc:354] 28 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_item (16 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287164.275647   13176 data_spec_inference.cc:354] 671 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_number (8 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287164.276452   13176 kernel.cc:802] Training dataset:
# Number of records: 891
# Number of columns: 12
#
# Number of columns by type:
# 	CATEGORICAL: 6 (50%)
# 	NUMERICAL: 5 (41.6667%)
# 	CATEGORICAL_SET: 1 (8.33333%)
#
# Columns:
#
# CATEGORICAL: 6 (50%)
# 	1: "Cabin" CATEGORICAL num-nas:687 (77.1044%) has-dict vocab-size:1 num-oods:204 (100%)
# 	2: "Embarked" CATEGORICAL num-nas:2 (0.224467%) has-dict vocab-size:4 zero-ood-items most-frequent:"S" 644 (72.4409%)
# 	7: "Sex" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"male" 577 (64.7587%)
# 	9: "Ticket_item" CATEGORICAL has-dict vocab-size:17 num-oods:46 (5.16274%) most-frequent:"NONE" 665 (74.6352%)
# 	10: "Ticket_number" CATEGORICAL has-dict vocab-size:9 num-oods:842 (94.5006%) most-frequent:"<OOD>" 842 (94.5006%)
# 	11: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 5 (41.6667%)
# 	0: "Age" NUMERICAL num-nas:177 (19.8653%) mean:29.6991 min:0.42 max:80 sd:14.5163
# 	3: "Fare" NUMERICAL mean:32.2042 min:0 max:512.329 sd:49.6655
# 	5: "Parch" NUMERICAL mean:0.381594 min:0 max:6 sd:0.805605
# 	6: "Pclass" NUMERICAL mean:2.30864 min:1 max:3 sd:0.835602
# 	8: "SibSp" NUMERICAL mean:0.523008 min:0 max:8 sd:1.10212
#
# CATEGORICAL_SET: 1 (8.33333%)
# 	4: "Name" CATEGORICAL_SET has-dict vocab-size:86 num-oods:1932 (216.835%) most-frequent:"<OOD>" 1932 (216.835%)
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1751287164.276540   13176 kernel.cc:818] Configure learner
# W0000 00:00:1751287164.276965   13176 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287164.276973   13176 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287164.276976   13176 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1751287164.277035   13176 kernel.cc:831] Training config:
# learner: "GRADIENT_BOOSTED_TREES"
# features: "^Age$"
# features: "^Cabin$"
# features: "^Embarked$"
# features: "^Fare$"
# features: "^Name$"
# features: "^Parch$"
# features: "^Pclass$"
# features: "^Sex$"
# features: "^SibSp$"
# features: "^Ticket_item$"
# features: "^Ticket_number$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# random_seed: 4
# metadata {
#   framework: "TF Keras"
# }
# pure_serving_model: false
# [yggdrasil_decision_forests.model.gradient_boosted_trees.proto.gradient_boosted_trees_config] {
#   num_trees: 300
#   decision_tree {
#     max_depth: 6
#     min_examples: 5
#     in_split_min_examples_check: true
#     keep_non_leaf_label_distribution: true
#     num_candidate_attributes: -1
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#     uplift {
#       min_examples_in_treatment: 5
#       split_score: KULLBACK_LEIBLER
#     }
#     honest {
#       ratio_leaf_examples: 0.5
#       fixed_separation: false
#     }
#     numerical_vector_sequence {
#       max_num_test_examples: 1000
#       num_random_selected_anchors: 100
#     }
#   }
#   shrinkage: 0.1
#   loss: DEFAULT
#   validation_set_ratio: 0.1
#   validation_interval_in_trees: 1
#   early_stopping: VALIDATION_LOSS_INCREASE
#   early_stopping_num_trees_look_ahead: 30
#   l2_regularization: 0
#   lambda_loss: 1
#   mart {
#   }
#   adapt_subsample_for_maximum_training_duration: false
#   l1_regularization: 0
#   use_hessian_gain: false
#   l2_regularization_categorical: 1
#   xe_ndcg {
#     ndcg_truncation: 5
#   }
#   stochastic_gradient_boosting {
#     ratio: 1
#   }
#   apply_link_function: true
#   compute_permutation_variable_importance: false
#   early_stopping_initial_iteration: 10
# }
#
# I0000 00:00:1751287164.277111   13176 kernel.cc:834] Deployment config:
# cache_path: "/tmp/tmpe4zyl_b9/working_cache"
# num_threads: 8
# try_resume_training: true
#
# I0000 00:00:1751287164.277221  106362 kernel.cc:895] Train model
# I0000 00:00:1751287164.277331  106362 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751287164.277341  106362 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 11 feature(s).
# I0000 00:00:1751287164.277755  106362 gradient_boosted_trees.cc:1230] 798 examples used for training and 93 examples used for validation
# I0000 00:00:1751287164.278237  106362 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751287164.280296  106362 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.249862 train-accuracy:0.607769 valid-loss:1.194693 valid-accuracy:0.688172 [total:0.00s iter:0.00s]
# I0000 00:00:1751287164.282096  106362 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.179283 train-accuracy:0.664160 valid-loss:1.139632 valid-accuracy:0.709677 [total:0.00s iter:0.00s]
# I0000 00:00:1751287164.374367  106362 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.871509
# I0000 00:00:1751287164.374389  106362 gradient_boosted_trees.cc:1669] Create final snapshot of the model at iteration 63
# I0000 00:00:1751287164.378296  106362 gradient_boosted_trees.cc:279] Truncates the model to 34 tree(s) i.e. 34  iteration(s).
# I0000 00:00:1751287164.378456  106362 gradient_boosted_trees.cc:341] Final model num-trees:34 valid-loss:0.871509 valid-accuracy:0.806452
# I0000 00:00:1751287164.378928  106362 kernel.cc:926] Export model in log directory: /tmp/tmpe4zyl_b9 with prefix 8bcd20c747e246ec
# I0000 00:00:1751287164.379980  106362 kernel.cc:944] Save model in resources
# I0000 00:00:1751287164.381321   13176 abstract_model.cc:921] Model self evaluation:
# Task: CLASSIFICATION
# Label: __LABEL
# Loss (BINOMIAL_LOG_LIKELIHOOD): 0.871509
#
# Accuracy: 0.806452  CI95[W][0 1]
# ErrorRate: : 0.193548
#
#
# Confusion Table:
# truth\prediction
#     1   2
# 1  54  10
# 2   8  21
# Total: 93
#
#
# 2025-06-30 21:39:24.390040: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1206] Loading model from path /tmp/tmpe4zyl_b9/model/ with prefix 8bcd20c747e246ec
# 2025-06-30 21:39:24.392878: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1035] Use fast generic engine
# i:5
# W0000 00:00:1751287164.624517   13176 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287164.624534   13176 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287164.624536   13176 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1751287164.810765   13176 kernel.cc:782] Start Yggdrasil model training
# ...
# 	2: "Embarked" CATEGORICAL num-nas:2 (0.224467%) has-dict vocab-size:4 zero-ood-items most-frequent:"S" 644 (72.4409%)
# 	7: "Sex" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"male" 577 (64.7587%)
# 	9: "Ticket_item" CATEGORICAL has-dict vocab-size:17 num-oods:46 (5.16274%) most-frequent:"NONE" 665 (74.6352%)
# 	10: "Ticket_number" CATEGORICAL has-dict vocab-size:9 num-oods:842 (94.5006%) most-frequent:"<OOD>" 842 (94.5006%)
# 	11: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 5 (41.6667%)
# 	0: "Age" NUMERICAL num-nas:177 (19.8653%) mean:29.6991 min:0.42 max:80 sd:14.5163
# 	3: "Fare" NUMERICAL mean:32.2042 min:0 max:512.329 sd:49.6655
# 	5: "Parch" NUMERICAL mean:0.381594 min:0 max:6 sd:0.805605
# 	6: "Pclass" NUMERICAL mean:2.30864 min:1 max:3 sd:0.835602
# 	8: "SibSp" NUMERICAL mean:0.523008 min:0 max:8 sd:1.10212
#
# CATEGORICAL_SET: 1 (8.33333%)
# 	4: "Name" CATEGORICAL_SET has-dict vocab-size:86 num-oods:1932 (216.835%) most-frequent:"<OOD>" 1932 (216.835%)
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1751287221.556218   13176 kernel.cc:818] Configure learner
# W0000 00:00:1751287221.556395   13176 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287221.556400   13176 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287221.556401   13176 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1751287221.556427   13176 kernel.cc:831] Training config:
# learner: "GRADIENT_BOOSTED_TREES"
# features: "^Age$"
# features: "^Cabin$"
# features: "^Embarked$"
# features: "^Fare$"
# features: "^Name$"
# features: "^Parch$"
# features: "^Pclass$"
# features: "^Sex$"
# features: "^SibSp$"
# features: "^Ticket_item$"
# features: "^Ticket_number$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# random_seed: 98
# metadata {
#   framework: "TF Keras"
# }
# pure_serving_model: false
# [yggdrasil_decision_forests.model.gradient_boosted_trees.proto.gradient_boosted_trees_config] {
#   num_trees: 300
#   decision_tree {
#     max_depth: 6
#     min_examples: 5
#     in_split_min_examples_check: true
#     keep_non_leaf_label_distribution: true
#     num_candidate_attributes: -1
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#     uplift {
#       min_examples_in_treatment: 5
#       split_score: KULLBACK_LEIBLER
#     }
#     honest {
#       ratio_leaf_examples: 0.5
#       fixed_separation: false
#     }
#     numerical_vector_sequence {
#       max_num_test_examples: 1000
#       num_random_selected_anchors: 100
#     }
#   }
#   shrinkage: 0.1
#   loss: DEFAULT
#   validation_set_ratio: 0.1
#   validation_interval_in_trees: 1
#   early_stopping: VALIDATION_LOSS_INCREASE
#   early_stopping_num_trees_look_ahead: 30
#   l2_regularization: 0
#   lambda_loss: 1
#   mart {
#   }
#   adapt_subsample_for_maximum_training_duration: false
#   l1_regularization: 0
#   use_hessian_gain: false
#   l2_regularization_categorical: 1
#   xe_ndcg {
#     ndcg_truncation: 5
#   }
#   stochastic_gradient_boosting {
#     ratio: 1
#   }
#   apply_link_function: true
#   compute_permutation_variable_importance: false
#   early_stopping_initial_iteration: 10
# }
#
# I0000 00:00:1751287221.556507   13176 kernel.cc:834] Deployment config:
# cache_path: "/tmp/tmp9waeilgr/working_cache"
# num_threads: 8
# try_resume_training: true
#
# I0000 00:00:1751287221.556640  185359 kernel.cc:895] Train model
# I0000 00:00:1751287221.556754  185359 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751287221.556765  185359 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 11 feature(s).
# I0000 00:00:1751287221.557278  185359 gradient_boosted_trees.cc:1230] 803 examples used for training and 88 examples used for validation
# I0000 00:00:1751287221.557779  185359 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751287221.559740  185359 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.236369 train-accuracy:0.620174 valid-loss:1.276384 valid-accuracy:0.579545 [total:0.00s iter:0.00s]
# I0000 00:00:1751287221.561374  185359 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.167167 train-accuracy:0.618929 valid-loss:1.208825 valid-accuracy:0.590909 [total:0.00s iter:0.00s]
# I0000 00:00:1751287221.676792  185359 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.781304
# I0000 00:00:1751287221.676816  185359 gradient_boosted_trees.cc:1669] Create final snapshot of the model at iteration 78
# I0000 00:00:1751287221.679252  185359 gradient_boosted_trees.cc:279] Truncates the model to 49 tree(s) i.e. 49  iteration(s).
# I0000 00:00:1751287221.679425  185359 gradient_boosted_trees.cc:341] Final model num-trees:49 valid-loss:0.781304 valid-accuracy:0.829545
# I0000 00:00:1751287221.679902  185359 kernel.cc:926] Export model in log directory: /tmp/tmp9waeilgr with prefix cec3ed5c1c584831
# I0000 00:00:1751287221.681105  185359 kernel.cc:944] Save model in resources
# I0000 00:00:1751287221.682185   13176 abstract_model.cc:921] Model self evaluation:
# Task: CLASSIFICATION
# Label: __LABEL
# Loss (BINOMIAL_LOG_LIKELIHOOD): 0.781304
#
# Accuracy: 0.829545  CI95[W][0 1]
# ErrorRate: : 0.170455
#
#
# Confusion Table:
# truth\prediction
#     1   2
# 1  45   6
# 2   9  28
# Total: 88
#
#
# 2025-06-30 21:40:21.690452: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1206] Loading model from path /tmp/tmp9waeilgr/model/ with prefix cec3ed5c1c584831
# 2025-06-30 21:40:21.693933: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1035] Use fast generic engine
# i:99
# W0000 00:00:1751287221.908366   13176 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287221.908383   13176 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287221.908387   13176 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1751287222.103411   13176 kernel.cc:782] Start Yggdrasil model training
# I0000 00:00:1751287222.103428   13176 kernel.cc:783] Collect training examples
# I0000 00:00:1751287222.103433   13176 kernel.cc:795] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# column_guides {
#   column_name_pattern: "^Pclass$"
# }
# column_guides {
#   column_name_pattern: "^Name$"
# }
# column_guides {
#   column_name_pattern: "^Sex$"
# }
# column_guides {
#   column_name_pattern: "^Age$"
# }
# column_guides {
#   column_name_pattern: "^SibSp$"
# }
# column_guides {
#   column_name_pattern: "^Parch$"
# }
# column_guides {
#   column_name_pattern: "^Fare$"
# }
# column_guides {
#   column_name_pattern: "^Cabin$"
# }
# column_guides {
#   column_name_pattern: "^Embarked$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_number$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_item$"
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: true
# detect_numerical_as_discretized_numerical: false
#
# I0000 00:00:1751287222.103598   13176 kernel.cc:401] Number of batches: 1
# I0000 00:00:1751287222.103602   13176 kernel.cc:402] Number of examples: 891
# I0000 00:00:1751287222.104027   13176 data_spec_inference.cc:354] 147 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Cabin (0 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287222.104292   13176 data_spec_inference.cc:354] 1441 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Name (85 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287222.104381   13176 data_spec_inference.cc:354] 28 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_item (16 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287222.104491   13176 data_spec_inference.cc:354] 671 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_number (8 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1751287222.104812   13176 kernel.cc:802] Training dataset:
# Number of records: 891
# Number of columns: 12
#
# Number of columns by type:
# 	CATEGORICAL: 6 (50%)
# 	NUMERICAL: 5 (41.6667%)
# 	CATEGORICAL_SET: 1 (8.33333%)
#
# Columns:
#
# CATEGORICAL: 6 (50%)
# 	1: "Cabin" CATEGORICAL num-nas:687 (77.1044%) has-dict vocab-size:1 num-oods:204 (100%)
# 	2: "Embarked" CATEGORICAL num-nas:2 (0.224467%) has-dict vocab-size:4 zero-ood-items most-frequent:"S" 644 (72.4409%)
# 	7: "Sex" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"male" 577 (64.7587%)
# 	9: "Ticket_item" CATEGORICAL has-dict vocab-size:17 num-oods:46 (5.16274%) most-frequent:"NONE" 665 (74.6352%)
# 	10: "Ticket_number" CATEGORICAL has-dict vocab-size:9 num-oods:842 (94.5006%) most-frequent:"<OOD>" 842 (94.5006%)
# 	11: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 5 (41.6667%)
# 	0: "Age" NUMERICAL num-nas:177 (19.8653%) mean:29.6991 min:0.42 max:80 sd:14.5163
# 	3: "Fare" NUMERICAL mean:32.2042 min:0 max:512.329 sd:49.6655
# 	5: "Parch" NUMERICAL mean:0.381594 min:0 max:6 sd:0.805605
# 	6: "Pclass" NUMERICAL mean:2.30864 min:1 max:3 sd:0.835602
# 	8: "SibSp" NUMERICAL mean:0.523008 min:0 max:8 sd:1.10212
#
# CATEGORICAL_SET: 1 (8.33333%)
# 	4: "Name" CATEGORICAL_SET has-dict vocab-size:86 num-oods:1932 (216.835%) most-frequent:"<OOD>" 1932 (216.835%)
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1751287222.104831   13176 kernel.cc:818] Configure learner
# W0000 00:00:1751287222.104968   13176 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287222.104972   13176 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1751287222.104974   13176 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1751287222.105001   13176 kernel.cc:831] Training config:
# learner: "GRADIENT_BOOSTED_TREES"
# features: "^Age$"
# features: "^Cabin$"
# features: "^Embarked$"
# features: "^Fare$"
# features: "^Name$"
# features: "^Parch$"
# features: "^Pclass$"
# features: "^Sex$"
# features: "^SibSp$"
# features: "^Ticket_item$"
# features: "^Ticket_number$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# random_seed: 99
# metadata {
#   framework: "TF Keras"
# }
# pure_serving_model: false
# [yggdrasil_decision_forests.model.gradient_boosted_trees.proto.gradient_boosted_trees_config] {
#   num_trees: 300
#   decision_tree {
#     max_depth: 6
#     min_examples: 5
#     in_split_min_examples_check: true
#     keep_non_leaf_label_distribution: true
#     num_candidate_attributes: -1
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#     uplift {
#       min_examples_in_treatment: 5
#       split_score: KULLBACK_LEIBLER
#     }
#     honest {
#       ratio_leaf_examples: 0.5
#       fixed_separation: false
#     }
#     numerical_vector_sequence {
#       max_num_test_examples: 1000
#       num_random_selected_anchors: 100
#     }
#   }
#   shrinkage: 0.1
#   loss: DEFAULT
#   validation_set_ratio: 0.1
#   validation_interval_in_trees: 1
#   early_stopping: VALIDATION_LOSS_INCREASE
#   early_stopping_num_trees_look_ahead: 30
#   l2_regularization: 0
#   lambda_loss: 1
#   mart {
#   }
#   adapt_subsample_for_maximum_training_duration: false
#   l1_regularization: 0
#   use_hessian_gain: false
#   l2_regularization_categorical: 1
#   xe_ndcg {
#     ndcg_truncation: 5
#   }
#   stochastic_gradient_boosting {
#     ratio: 1
#   }
#   apply_link_function: true
#   compute_permutation_variable_importance: false
#   early_stopping_initial_iteration: 10
# }
#
# I0000 00:00:1751287222.105051   13176 kernel.cc:834] Deployment config:
# cache_path: "/tmp/tmp8c1zzmgp/working_cache"
# num_threads: 8
# try_resume_training: true
#
# I0000 00:00:1751287222.105132  186057 kernel.cc:895] Train model
# I0000 00:00:1751287222.105207  186057 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1751287222.105213  186057 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 11 feature(s).
# I0000 00:00:1751287222.105770  186057 gradient_boosted_trees.cc:1230] 801 examples used for training and 90 examples used for validation
# I0000 00:00:1751287222.106475  186057 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1751287222.108374  186057 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.231308 train-accuracy:0.629214 valid-loss:1.359612 valid-accuracy:0.500000 [total:0.00s iter:0.00s]
# I0000 00:00:1751287222.110081  186057 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.156309 train-accuracy:0.629214 valid-loss:1.279672 valid-accuracy:0.500000 [total:0.00s iter:0.00s]
# I0000 00:00:1751287222.114040  186057 gradient_boosted_trees.cc:1634] Train tree 3/300 train-loss:1.098874 train-accuracy:0.789014 valid-loss:1.220186 valid-accuracy:0.688889 [total:0.01s iter:0.00s]
# I0000 00:00:1751287222.330878  186057 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.797904
# I0000 00:00:1751287222.330907  186057 gradient_boosted_trees.cc:1669] Create final snapshot of the model at iteration 130
# I0000 00:00:1751287222.335527  186057 gradient_boosted_trees.cc:279] Truncates the model to 101 tree(s) i.e. 101  iteration(s).
# I0000 00:00:1751287222.335682  186057 gradient_boosted_trees.cc:341] Final model num-trees:101 valid-loss:0.797904 valid-accuracy:0.822222
# I0000 00:00:1751287222.336441  186057 kernel.cc:926] Export model in log directory: /tmp/tmp8c1zzmgp with prefix 515f819aa5574221
# I0000 00:00:1751287222.338286  186057 kernel.cc:944] Save model in resources
# I0000 00:00:1751287222.339407   13176 abstract_model.cc:921] Model self evaluation:
# Task: CLASSIFICATION
# Label: __LABEL
# Loss (BINOMIAL_LOG_LIKELIHOOD): 0.797904
#
# Accuracy: 0.822222  CI95[W][0 1]
# ErrorRate: : 0.177778
#
#
# Confusion Table:
# truth\prediction
#     1   2
# 1  39   6
# 2  10  35
# Total: 90
#
#
# 2025-06-30 21:40:22.349597: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1206] Loading model from path /tmp/tmp8c1zzmgp/model/ with prefix 515f819aa5574221
# 2025-06-30 21:40:22.356179: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1035] Use fast generic engine
# Submission exported to submission.csv

# %%
make_submission(kaggle_predictions)
# Out:
# Submission exported to submission.csv
